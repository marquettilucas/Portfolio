# %% [markdown]
# # #002 Quick Guide on how to obtain financial data in a python program

# %% [markdown]
# For future projects:
# - export and organize data on CSV file
# - run an import code to perform some analysis over financial statements

# %% [markdown]
# install std Libraries

# %%
#    !pip install pandas
#    !pip install pandas-datareader
#    !pip install yfinance
#    !pip install datetime
#    !pip install plotly_express

# %%
# import libs
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import yfinance as yf
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go

yf.pdr_override()

# %% [markdown]
# ## 1 Define and create a Ticker object

# %%
# define Ticker code from User input
stock = input("Please, enter the Ticker code: ")
# create a ticker object with a ticker symbol
stock = yf.Ticker(stock)
stock
# Out:
# Please, enter the Ticker code: JPM
# yfinance.Ticker object <JPM>

# %% [markdown]
# ## 2 Obtain financial statement data

# %% [markdown]
# once created the ticker object,
#  we can search for some info about company inputed:
#
# ![image.png](attachment:image.png)

# %%
#show some recent news about company
display(stock.news)
# Out:
# [{'uuid': '1c1e2602-72e1-312c-8464-0cce1ae54a75',
#   'title': 'JPMorgan Chase & Co. (NYSE:JPM) is largely controlled by institutional shareholders who own 72% of the company',
#   'publisher': 'Simply Wall St.',
#   'link': 'https://finance.yahoo.com/news/jpmorgan-chase-co-nyse-jpm-140012870.html',
#   'providerPublishTime': 1699711212,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/D93sD4I.HCnjhHDLRpJ19A--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/393a21695c25a8a00f631cfd22c3f87a',
#      'width': 1194,
#      'height': 432,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/l9ri62WDH1LpMIr8qHol6Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/393a21695c25a8a00f631cfd22c3f87a',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['JPM']},
# ...

# %%
display(stock.balance_sheet)
# Out:
#                                                    2022-12-31  \
# Treasury Shares Number                           1170676094.0
# Preferred Shares Number                           391850000.0
# Ordinary Shares Number                           2934257801.0
# Share Issued                                     4104933895.0
# Net Debt                                                  NaN
# Total Debt                                     466727000000.0
# Tangible Book Value                            204069000000.0
# Invested Capital                               731655000000.0
# Net Tangible Assets                            231473000000.0
# Common Stock Equity                            264928000000.0
# Preferred Stock Equity                          27404000000.0
# Total Capitalization                           715032000000.0
# Total Equity Gross Minority Interest           292332000000.0
# Stockholders Equity                            292332000000.0
# ...

# %%
display(stock.income_stmt)
# Out:
#                                                             2022-12-31  \
# Tax Effect Of Unusual Items                           -48917818.307846
# Tax Rate For Calcs                                            0.183902
# Total Unusual Items                                       -266000000.0
# Total Unusual Items Excluding Goodwill                    -266000000.0
# Net Income From Continuing Operation Net Minori...       37676000000.0
# Reconciled Depreciation                                   7051000000.0
# Net Interest Income                                      66710000000.0
# Interest Expense                                         26097000000.0
# Interest Income                                          92807000000.0
# Normalized Income                                   37893082181.692154
# Net Income From Continuing And Discontinued Ope...       37676000000.0
# Diluted Average Shares                                    2970000000.0
# ...

# %%
display(stock.cashflow)
# Out:
#                                                     2022-12-31  \
# Free Cash Flow                                  107119000000.0
# Repurchase Of Capital Stock                     -10596000000.0
# Repayment Of Debt                               -45556000000.0
# Issuance Of Debt                                 78442000000.0
# Issuance Of Capital Stock                                  0.0
# Interest Paid Supplemental Data                  23143000000.0
# Income Tax Paid Supplemental Data                 4355000000.0
# End Cash Position                               567234000000.0
# Beginning Cash Position                         740834000000.0
# Effect Of Exchange Rate Changes                 -16643000000.0
# Changes In Cash                                -156957000000.0
# Financing Cash Flow                            -126257000000.0
# Cash Flow From Continuing Financing Activities -126257000000.0
# Net Other Financing Charges                       2439000000.0
# ...
