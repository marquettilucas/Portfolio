# %% [markdown]
# # #011 - Portfolio Optimization

# %% [markdown]
# ## libs

# %%
#import Libraries
import pandas as pd
from pandas_datareader import data as pdr
import numpy as np
import random

# %% [markdown]
# ## Functions

# %%
def rand_weights(n):
    ''' Produces n random weights that sum to 1 '''
    k = np.random.rand(n)
    return k / sum(k)

# %%
def run_portfolio(df, weights, initial_investment, risk_free):
    ''' Performs an asset allocation and calc Portfolio Metrics'''
    # The function returns: 
    # (0) Portfolio Data Frame 
    # (1) Expected portfolio return 
    # (2) Expected volatility 
    # (3) Sharpe ratio 
    # (4) Return on investment 
    # (5) Final portfolio value in dollars
    
    # Perform asset allocation using the random weights (sent as arguments to the function)
    portfolio_df =  df.copy()
    # Scale stock prices using the "price_scaling"
    scaled_df = df.copy()
    for i in df.columns[0:]:
        scaled_df[i] = df[i]/df[i][0]
    #enumerate method links Stocks tickers in columns along with a counter position weight (i), like an index
    for i, stock in enumerate(scaled_df):
        portfolio_df[stock] = weights[i] * scaled_df[stock]  * initial_investment
    
    # Sum up all values and place the result in a new column titled "portfolio value [$]" 
    portfolio_df['Total Value [$]'] = portfolio_df.sum(axis = 1, numeric_only = True)
    # Calculate the portfolio percentage daily return and replace NaNs with zeros
    portfolio_df['Daily Return [%]'] = portfolio_df['Total Value [$]'].pct_change(1) * 100 
    portfolio_df.replace(np.nan, 0, inplace = True)
    # Calculate the return on the investment = last final value of the portfolio compared to its initial value
    return_on_investment = ((portfolio_df['Total Value [$]'][-1:] - portfolio_df['Total Value [$]'][0]) 
                            / portfolio_df['Total Value [$]'][0]) * 100
    
    # Daily change of every stock in the portfolio 
    portfolio_daily_return_df = portfolio_df.drop(columns = ['Total Value [$]', 'Daily Return [%]'])
    portfolio_daily_return_df = portfolio_daily_return_df.pct_change(1)
    portfolio_daily_return_df.replace(np.nan, 0, inplace = True)  
  
    # Portfolio Expected Return formula
    expected_portfolio_return = np.sum(weights * portfolio_daily_return_df.mean() ) * 252
  
    # Portfolio standard deviation, volatility (risk)
    covariance = portfolio_daily_return_df.cov() * 252 
    expected_volatility = np.sqrt(np.dot(weights.T, np.dot(covariance, weights)))
    
    # Calculate Sharpe ratio
    sharpe_ratio = (expected_portfolio_return - risk_free)/expected_volatility 
    
    return expected_portfolio_return, expected_volatility, sharpe_ratio, portfolio_df['Total Value [$]'][-1:].values[0], return_on_investment.values[0]

# %% [markdown]
# ## 11.1 Read and Organize Data and Run Simulations

# %%
# file_name =          input('Input the CSV file name: ')
# initial_investment = int(input('Input the initial investment: '))
# risk_free =          float(input('Input the risk free annual rate: ')) # https://ycharts.com/ind icators/10_year_treasury_rate 
# sim_runs =           int(input('Input how many runs to perform on Monte Carlo Simulation: '))

file_name =          'MAG7'
initial_investment = 1000000
risk_free =          0.039
sim_runs =           1000

# %%
# read CSV file
df = pd.read_csv(file_name)
# replace the colum Date to Index
df.set_index(['Date'], inplace = True)

# %%
# Set the number of simulation runs
n = n_assets = len(df.columns)

# Array to store all weights
weights_runs = np.zeros((sim_runs, n))
# Array to store all Sharpe ratios
sharpe_ratio_runs = np.zeros(sim_runs)
# Array to store all expected returns
expected_portfolio_returns_runs = np.zeros(sim_runs)
# Array to store all volatility values
volatility_runs = np.zeros(sim_runs)
# Array to store all returns on investment
return_on_investment_runs = np.zeros(sim_runs)
# Array to store all final portfolio values
final_value_runs = np.zeros(sim_runs)

# RUN MONTE CARLO SIMS
for i in range(sim_runs):
    # Generate random weights 
    weights = rand_weights(n)
    # Store the weights
    weights_runs[i,:] = weights
    
    # Call 'run_portfolio' function and store Sharpe ratio, return and volatility 
    expected_portfolio_returns_runs[i], volatility_runs[i], sharpe_ratio_runs[i], final_value_runs[i], return_on_investment_runs[i] = run_portfolio(df, weights, initial_investment, risk_free)
    print("Simulation Run = {}".format(i))   
    print("Weights = {}, Final Value = ${:.2f}, Sharpe Ratio = {:.2f}".format(weights_runs[i].round(3), final_value_runs[i], sharpe_ratio_runs[i]))   
    print('\n')
# Out:
# Simulation Run = 0
# Weights = [0.063 0.133 0.191 0.177 0.203 0.125 0.108], Final Value = $4895060.84, Sharpe Ratio = 0.98
#
#
# Simulation Run = 1
# Weights = [0.057 0.09  0.108 0.206 0.231 0.298 0.01 ], Final Value = $6065196.17, Sharpe Ratio = 1.02
#
#
# Simulation Run = 2
# Weights = [0.075 0.241 0.171 0.028 0.021 0.256 0.207], Final Value = $6773490.91, Sharpe Ratio = 1.09
#
#
# Simulation Run = 3
# Weights = [0.037 0.246 0.009 0.243 0.182 0.2   0.082], Final Value = $5323564.44, Sharpe Ratio = 0.96
#
#
# Simulation Run = 4
# Weights = [0.175 0.151 0.154 0.137 0.184 0.102 0.098], Final Value = $4817427.97, Sharpe Ratio = 1.00
#
#
# Simulation Run = 5
# Weights = [0.156 0.117 0.061 0.18  0.166 0.141 0.179], Final Value = $5762343.27, Sharpe Ratio = 1.07
#
#
# Simulation Run = 6
# Weights = [0.193 0.078 0.153 0.151 0.151 0.121 0.152], Final Value = $5461456.85, Sharpe Ratio = 1.07
#
#
# Simulation Run = 7
# Weights = [0.198 0.01  0.251 0.142 0.029 0.172 0.198], Final Value = $6246601.76, Sharpe Ratio = 1.11
#
#
# Simulation Run = 8
# Weights = [0.168 0.008 0.094 0.108 0.375 0.099 0.148], Final Value = $5462043.12, Sharpe Ratio = 1.10
#
#
# Simulation Run = 9
# Weights = [0.199 0.101 0.005 0.254 0.111 0.224 0.106], Final Value = $6147308.50, Sharpe Ratio = 1.07
#
#
# Simulation Run = 10
# Weights = [0.003 0.183 0.191 0.24  0.106 0.078 0.198], Final Value = $4748159.05, Sharpe Ratio = 0.94
#
#
# Simulation Run = 11
# Weights = [0.181 0.114 0.158 0.024 0.19  0.045 0.289], Final Value = $5663213.23, Sharpe Ratio = 1.08
#
#
# Simulation Run = 12
# Weights = [0.073 0.226 0.106 0.136 0.182 0.157 0.12 ], Final Value = $5271479.14, Sharpe Ratio = 1.00
#
#
# Simulation Run = 13
# Weights = [0.048 0.288 0.289 0.    0.207 0.026 0.142], Final Value = $3997011.47, Sharpe Ratio = 0.90
#
#
# Simulation Run = 14
# Weights = [0.135 0.23  0.216 0.06  0.083 0.226 0.051], Final Value = $5539150.78, Sharpe Ratio = 1.00
#
#
# Simulation Run = 15
# Weights = [0.21  0.016 0.043 0.227 0.15  0.174 0.179], Final Value = $6279096.96, Sharpe Ratio = 1.12
#
#
# Simulation Run = 16
# Weights = [0.054 0.08  0.144 0.049 0.16  0.339 0.174], Final Value = $7627815.98, Sharpe Ratio = 1.16
#
#
# Simulation Run = 17
# Weights = [0.265 0.121 0.122 0.24  0.006 0.245 0.002], Final Value = $5639845.80, Sharpe Ratio = 0.99
#
#
# Simulation Run = 18
# Weights = [0.264 0.532 0.02  0.007 0.02  0.096 0.061], Final Value = $4269772.57, Sharpe Ratio = 0.85
#
#
# Simulation Run = 19
# Weights = [0.171 0.197 0.095 0.139 0.182 0.019 0.197], Final Value = $4607085.05, Sharpe Ratio = 0.99
#
#
# Simulation Run = 20
# Weights = [0.276 0.142 0.088 0.23  0.133 0.043 0.088], Final Value = $4286562.14, Sharpe Ratio = 0.95
#
#
# Simulation Run = 21
# Weights = [0.274 0.11  0.024 0.291 0.126 0.141 0.035], Final Value = $4934814.34, Sharpe Ratio = 0.97
#
#
# Simulation Run = 22
# Weights = [0.064 0.077 0.214 0.173 0.013 0.314 0.145], Final Value = $6980248.79, Sharpe Ratio = 1.10
#
#
# Simulation Run = 23
# Weights = [0.232 0.183 0.15  0.103 0.072 0.086 0.174], Final Value = $5183511.34, Sharpe Ratio = 1.03
#
#
# Simulation Run = 24
# Weights = [0.285 0.    0.235 0.014 0.002 0.19  0.273], Final Value = $7187326.52, Sharpe Ratio = 1.18
#
#
# Simulation Run = 25
# Weights = [0.082 0.145 0.258 0.111 0.162 0.013 0.23 ], Final Value = $4597196.58, Sharpe Ratio = 0.98
#
#
# Simulation Run = 26
# Weights = [0.124 0.194 0.122 0.22  0.125 0.046 0.169], Final Value = $4504089.27, Sharpe Ratio = 0.95
#
#
# Simulation Run = 27
# Weights = [0.065 0.168 0.032 0.094 0.044 0.373 0.224], Final Value = $8170120.07, Sharpe Ratio = 1.15
#
#
# Simulation Run = 28
# Weights = [0.116 0.027 0.083 0.23  0.277 0.117 0.15 ], Final Value = $5387552.12, Sharpe Ratio = 1.06
#
#
# Simulation Run = 29
# Weights = [0.097 0.159 0.2   0.136 0.062 0.107 0.238], Final Value = $5553972.49, Sharpe Ratio = 1.03
#
#
# Simulation Run = 30
# Weights = [0.2   0.043 0.174 0.227 0.091 0.193 0.071], Final Value = $5594883.55, Sharpe Ratio = 1.04
#
#
# Simulation Run = 31
# Weights = [0.031 0.272 0.054 0.141 0.229 0.252 0.02 ], Final Value = $5477507.96, Sharpe Ratio = 0.96
#
#
# Simulation Run = 32
# Weights = [0.312 0.132 0.199 0.149 0.042 0.001 0.165], Final Value = $4402480.98, Sharpe Ratio = 0.99
#
#
# Simulation Run = 33
# Weights = [0.204 0.193 0.076 0.036 0.189 0.134 0.167], Final Value = $5728096.61, Sharpe Ratio = 1.08
#
#
# Simulation Run = 34
# Weights = [0.103 0.188 0.168 0.143 0.083 0.198 0.119], Final Value = $5664922.38, Sharpe Ratio = 1.03
#
#
# Simulation Run = 35
# Weights = [0.124 0.014 0.241 0.216 0.062 0.182 0.161], Final Value = $5940050.29, Sharpe Ratio = 1.07
#
#
# Simulation Run = 36
# Weights = [0.013 0.3   0.092 0.145 0.302 0.042 0.105], Final Value = $3890033.74, Sharpe Ratio = 0.87
#
#
# Simulation Run = 37
# Weights = [0.194 0.11  0.201 0.13  0.123 0.143 0.1  ], Final Value = $5267941.81, Sharpe Ratio = 1.04
#
#
# Simulation Run = 38
# Weights = [0.175 0.056 0.164 0.174 0.191 0.14  0.1  ], Final Value = $5304468.02, Sharpe Ratio = 1.05
#
#
# Simulation Run = 39
# Weights = [0.141 0.187 0.151 0.153 0.096 0.143 0.128], Final Value = $5257066.10, Sharpe Ratio = 1.01
#
#
# Simulation Run = 40
# Weights = [0.079 0.064 0.23  0.277 0.003 0.116 0.231], Final Value = $5521060.87, Sharpe Ratio = 1.01
#
#
# Simulation Run = 41
# Weights = [0.249 0.228 0.088 0.14  0.199 0.011 0.086], Final Value = $3903123.97, Sharpe Ratio = 0.92
#
#
# Simulation Run = 42
# Weights = [0.226 0.061 0.14  0.183 0.067 0.153 0.17 ], Final Value = $5910702.05, Sharpe Ratio = 1.09
#
#
# Simulation Run = 43
# Weights = [0.233 0.053 0.058 0.26  0.19  0.167 0.039], Final Value = $5268309.08, Sharpe Ratio = 1.02
#
#
# Simulation Run = 44
# Weights = [0.096 0.197 0.216 0.199 0.11  0.176 0.007], Final Value = $4628356.93, Sharpe Ratio = 0.90
#
#
# Simulation Run = 45
# Weights = [0.117 0.194 0.033 0.216 0.139 0.211 0.09 ], Final Value = $5681223.34, Sharpe Ratio = 1.02
#
#
# Simulation Run = 46
# Weights = [0.104 0.202 0.071 0.187 0.311 0.045 0.08 ], Final Value = $4022107.39, Sharpe Ratio = 0.91
#
#
# Simulation Run = 47
# Weights = [0.071 0.012 0.148 0.102 0.254 0.313 0.1  ], Final Value = $7005022.13, Sharpe Ratio = 1.14
#
#
# Simulation Run = 48
# Weights = [0.116 0.113 0.1   0.038 0.183 0.137 0.315], Final Value = $6648482.62, Sharpe Ratio = 1.12
#
#
# Simulation Run = 49
# Weights = [0.209 0.187 0.161 0.003 0.139 0.128 0.173], Final Value = $5673937.76, Sharpe Ratio = 1.08
#
#
# Simulation Run = 50
# Weights = [0.048 0.165 0.239 0.268 0.01  0.169 0.101], Final Value = $5011879.57, Sharpe Ratio = 0.93
#
#
# Simulation Run = 51
# Weights = [0.263 0.021 0.01  0.24  0.076 0.211 0.18 ], Final Value = $6706582.82, Sharpe Ratio = 1.14
#
#
# Simulation Run = 52
# Weights = [0.017 0.096 0.215 0.136 0.272 0.196 0.07 ], Final Value = $5379192.34, Sharpe Ratio = 1.01
#
#
# Simulation Run = 53
# Weights = [0.367 0.093 0.035 0.144 0.202 0.056 0.102], Final Value = $4877155.47, Sharpe Ratio = 1.05
#
#
# Simulation Run = 54
# Weights = [0.098 0.096 0.155 0.07  0.126 0.2   0.255], Final Value = $6790593.06, Sharpe Ratio = 1.13
#
#
# Simulation Run = 55
# Weights = [0.063 0.259 0.246 0.121 0.137 0.149 0.025], Final Value = $4404434.07, Sharpe Ratio = 0.88
#
#
# Simulation Run = 56
# Weights = [0.229 0.035 0.003 0.025 0.223 0.301 0.184], Final Value = $7817212.01, Sharpe Ratio = 1.22
#
#
# Simulation Run = 57
# Weights = [0.237 0.102 0.038 0.033 0.272 0.093 0.225], Final Value = $5938326.70, Sharpe Ratio = 1.13
#
#
# Simulation Run = 58
# Weights = [0.025 0.186 0.136 0.245 0.07  0.23  0.108], Final Value = $5709623.52, Sharpe Ratio = 0.99
#
#
# Simulation Run = 59
# Weights = [0.067 0.238 0.193 0.102 0.09  0.222 0.088], Final Value = $5598502.20, Sharpe Ratio = 1.00
#
#
# Simulation Run = 60
# Weights = [0.055 0.051 0.108 0.255 0.246 0.052 0.234], Final Value = $5096757.03, Sharpe Ratio = 1.02
#
#
# Simulation Run = 61
# Weights = [0.157 0.076 0.087 0.245 0.052 0.084 0.3  ], Final Value = $5905237.58, Sharpe Ratio = 1.06
#
#
# Simulation Run = 62
# Weights = [0.221 0.054 0.067 0.063 0.167 0.282 0.146], Final Value = $7242405.92, Sharpe Ratio = 1.18
#
#
# Simulation Run = 63
# Weights = [0.282 0.233 0.078 0.016 0.051 0.107 0.233], Final Value = $5914242.11, Sharpe Ratio = 1.08
#
#
# Simulation Run = 64
# Weights = [0.2   0.135 0.148 0.005 0.197 0.214 0.101], Final Value = $6144365.85, Sharpe Ratio = 1.11
#
#
# Simulation Run = 65
# Weights = [0.218 0.103 0.023 0.089 0.166 0.27  0.131], Final Value = $6957095.01, Sharpe Ratio = 1.16
#
#
# Simulation Run = 66
# Weights = [0.2   0.081 0.115 0.186 0.102 0.099 0.217], Final Value = $5648281.53, Sharpe Ratio = 1.07
#
#
# Simulation Run = 67
# Weights = [0.116 0.06  0.045 0.2   0.09  0.279 0.21 ], Final Value = $7293286.30, Sharpe Ratio = 1.14
#
#
# Simulation Run = 68
# Weights = [0.168 0.085 0.098 0.134 0.166 0.172 0.177], Final Value = $6140172.32, Sharpe Ratio = 1.11
#
#
# Simulation Run = 69
# Weights = [0.017 0.013 0.242 0.398 0.089 0.09  0.152], Final Value = $4637672.13, Sharpe Ratio = 0.92
#
#
# Simulation Run = 70
# Weights = [0.156 0.155 0.038 0.197 0.19  0.097 0.166], Final Value = $5205801.64, Sharpe Ratio = 1.03
#
#
# Simulation Run = 71
# Weights = [0.062 0.203 0.154 0.154 0.161 0.148 0.118], Final Value = $5126962.67, Sharpe Ratio = 0.99
#
#
# Simulation Run = 72
# Weights = [0.22  0.154 0.02  0.281 0.181 0.077 0.066], Final Value = $4392661.89, Sharpe Ratio = 0.94
#
#
# Simulation Run = 73
# Weights = [0.245 0.183 0.062 0.098 0.22  0.016 0.175], Final Value = $4659444.39, Sharpe Ratio = 1.01
#
#
# Simulation Run = 74
# Weights = [0.174 0.189 0.133 0.194 0.073 0.12  0.117], Final Value = $4977645.64, Sharpe Ratio = 0.99
#
#
# Simulation Run = 75
# Weights = [0.296 0.261 0.005 0.053 0.061 0.054 0.269], Final Value = $5625895.57, Sharpe Ratio = 1.05
#
#
# Simulation Run = 76
# Weights = [0.145 0.102 0.217 0.22  0.124 0.145 0.047], Final Value = $4787690.77, Sharpe Ratio = 0.96
#
#
# Simulation Run = 77
# Weights = [0.019 0.217 0.203 0.128 0.187 0.142 0.104], Final Value = $4874760.35, Sharpe Ratio = 0.96
#
#
# Simulation Run = 78
# Weights = [0.234 0.041 0.178 0.24  0.085 0.049 0.173], Final Value = $4878045.84, Sharpe Ratio = 1.02
#
#
# Simulation Run = 79
# Weights = [0.259 0.23  0.086 0.091 0.212 0.018 0.104], Final Value = $4158426.46, Sharpe Ratio = 0.96
#
#
# Simulation Run = 80
# Weights = [0.147 0.205 0.058 0.2   0.029 0.12  0.241], Final Value = $5740622.38, Sharpe Ratio = 1.03
#
#
# Simulation Run = 81
# Weights = [0.153 0.007 0.097 0.259 0.135 0.109 0.24 ], Final Value = $5874566.61, Sharpe Ratio = 1.08
#
#
# Simulation Run = 82
# Weights = [0.122 0.054 0.007 0.11  0.161 0.272 0.274], Final Value = $7809594.91, Sharpe Ratio = 1.19
#
#
# Simulation Run = 83
# Weights = [0.117 0.032 0.123 0.091 0.177 0.239 0.221], Final Value = $7093040.46, Sharpe Ratio = 1.17
#
#
# Simulation Run = 84
# Weights = [0.035 0.076 0.21  0.1   0.215 0.152 0.211], Final Value = $5934995.54, Sharpe Ratio = 1.08
#
#
# Simulation Run = 85
# Weights = [0.1   0.138 0.271 0.047 0.109 0.255 0.08 ], Final Value = $6081896.62, Sharpe Ratio = 1.06
#
#
# Simulation Run = 86
# Weights = [0.    0.128 0.16  0.326 0.125 0.057 0.203], Final Value = $4596607.97, Sharpe Ratio = 0.93
#
#
# Simulation Run = 87
# Weights = [0.307 0.064 0.016 0.292 0.045 0.115 0.16 ], Final Value = $5579569.48, Sharpe Ratio = 1.06
#
#
# Simulation Run = 88
# Weights = [0.257 0.019 0.122 0.251 0.193 0.031 0.128], Final Value = $4554932.11, Sharpe Ratio = 1.00
#
#
# Simulation Run = 89
# Weights = [0.174 0.217 0.103 0.017 0.264 0.128 0.096], Final Value = $5160198.99, Sharpe Ratio = 1.03
#
#
# Simulation Run = 90
# Weights = [0.254 0.146 0.069 0.242 0.143 0.088 0.057], Final Value = $4500806.82, Sharpe Ratio = 0.95
#
#
# Simulation Run = 91
# Weights = [0.124 0.166 0.133 0.193 0.17  0.135 0.078], Final Value = $4871160.32, Sharpe Ratio = 0.97
#
#
# Simulation Run = 92
# Weights = [0.091 0.242 0.097 0.09  0.176 0.194 0.109], Final Value = $5616262.45, Sharpe Ratio = 1.02
#
#
# Simulation Run = 93
# Weights = [0.162 0.188 0.126 0.047 0.18  0.191 0.104], Final Value = $5773494.46, Sharpe Ratio = 1.07
#
#
# Simulation Run = 94
# Weights = [0.19  0.07  0.18  0.191 0.078 0.173 0.118], Final Value = $5667518.01, Sharpe Ratio = 1.06
#
#
# Simulation Run = 95
# Weights = [0.163 0.012 0.099 0.206 0.202 0.202 0.117], Final Value = $6089100.43, Sharpe Ratio = 1.10
#
#
# Simulation Run = 96
# Weights = [0.126 0.012 0.18  0.201 0.102 0.121 0.258], Final Value = $6046757.47, Sharpe Ratio = 1.09
#
#
# Simulation Run = 97
# Weights = [0.05  0.092 0.239 0.156 0.209 0.15  0.103], Final Value = $5142700.62, Sharpe Ratio = 1.01
#
#
# Simulation Run = 98
# Weights = [0.037 0.239 0.139 0.295 0.106 0.047 0.137], Final Value = $4009566.24, Sharpe Ratio = 0.86
#
#
# Simulation Run = 99
# Weights = [0.184 0.09  0.161 0.302 0.138 0.077 0.048], Final Value = $4168453.69, Sharpe Ratio = 0.90
#
#
# Simulation Run = 100
# Weights = [0.084 0.104 0.213 0.101 0.114 0.181 0.201], Final Value = $6149971.05, Sharpe Ratio = 1.09
#
#
# Simulation Run = 101
# Weights = [0.178 0.155 0.149 0.203 0.127 0.099 0.088], Final Value = $4643523.57, Sharpe Ratio = 0.97
#
#
# Simulation Run = 102
# Weights = [0.208 0.007 0.264 0.36  0.031 0.005 0.126], Final Value = $3949297.84, Sharpe Ratio = 0.89
#
#
# Simulation Run = 103
# Weights = [0.106 0.154 0.052 0.083 0.318 0.27  0.017], Final Value = $6025323.64, Sharpe Ratio = 1.05
#
#
# Simulation Run = 104
# Weights = [0.2   0.061 0.188 0.124 0.145 0.232 0.049], Final Value = $5930015.97, Sharpe Ratio = 1.07
#
#
# Simulation Run = 105
# Weights = [0.251 0.129 0.022 0.249 0.246 0.004 0.098], Final Value = $4026858.00, Sharpe Ratio = 0.94
#
#
# Simulation Run = 106
# Weights = [0.163 0.065 0.038 0.037 0.221 0.171 0.305], Final Value = $7128307.76, Sharpe Ratio = 1.17
#
#
# Simulation Run = 107
# Weights = [0.046 0.18  0.167 0.224 0.141 0.011 0.231], Final Value = $4418737.76, Sharpe Ratio = 0.93
#
#
# Simulation Run = 108
# Weights = [0.119 0.207 0.157 0.068 0.114 0.186 0.148], Final Value = $5834152.64, Sharpe Ratio = 1.06
#
#
# Simulation Run = 109
# Weights = [0.147 0.102 0.019 0.163 0.264 0.205 0.1  ], Final Value = $5980426.90, Sharpe Ratio = 1.09
#
#
# Simulation Run = 110
# Weights = [0.011 0.227 0.229 0.206 0.072 0.219 0.036], Final Value = $5032697.73, Sharpe Ratio = 0.91
#
#
# Simulation Run = 111
# Weights = [0.159 0.04  0.11  0.222 0.065 0.335 0.068], Final Value = $6951924.88, Sharpe Ratio = 1.10
#
#
# Simulation Run = 112
# Weights = [0.241 0.1   0.1   0.185 0.127 0.227 0.021], Final Value = $5707082.44, Sharpe Ratio = 1.04
#
#
# Simulation Run = 113
# Weights = [0.217 0.039 0.091 0.154 0.182 0.115 0.203], Final Value = $5880902.68, Sharpe Ratio = 1.11
#
#
# Simulation Run = 114
# Weights = [0.22  0.141 0.217 0.047 0.311 0.048 0.017], Final Value = $3951705.93, Sharpe Ratio = 0.93
#
#
# Simulation Run = 115
# Weights = [0.108 0.086 0.102 0.197 0.32  0.122 0.064], Final Value = $4825957.03, Sharpe Ratio = 0.99
#
#
# Simulation Run = 116
# Weights = [0.103 0.186 0.21  0.193 0.151 0.073 0.084], Final Value = $4172460.80, Sharpe Ratio = 0.91
#
#
# Simulation Run = 117
# Weights = [0.307 0.018 0.13  0.021 0.17  0.24  0.114], Final Value = $6811560.30, Sharpe Ratio = 1.18
#
#
# Simulation Run = 118
# Weights = [0.232 0.128 0.221 0.008 0.011 0.154 0.245], Final Value = $6404361.01, Sharpe Ratio = 1.12
#
#
# Simulation Run = 119
# Weights = [0.209 0.344 0.04  0.037 0.033 0.152 0.184], Final Value = $5763276.71, Sharpe Ratio = 1.03
#
#
# Simulation Run = 120
# Weights = [0.035 0.196 0.069 0.281 0.228 0.031 0.161], Final Value = $4181851.52, Sharpe Ratio = 0.91
#
#
# Simulation Run = 121
# Weights = [0.232 0.191 0.036 0.171 0.196 0.108 0.067], Final Value = $4768878.56, Sharpe Ratio = 0.99
#
#
# Simulation Run = 122
# Weights = [0.225 0.048 0.007 0.183 0.213 0.102 0.222], Final Value = $5919557.02, Sharpe Ratio = 1.11
#
#
# Simulation Run = 123
# Weights = [0.166 0.209 0.134 0.2   0.026 0.104 0.162], Final Value = $5038782.62, Sharpe Ratio = 0.99
#
#
# Simulation Run = 124
# Weights = [0.136 0.175 0.135 0.077 0.245 0.217 0.014], Final Value = $5417072.36, Sharpe Ratio = 1.01
#
#
# Simulation Run = 125
# Weights = [0.064 0.146 0.299 0.034 0.225 0.112 0.12 ], Final Value = $4902158.10, Sharpe Ratio = 1.00
#
#
# Simulation Run = 126
# Weights = [0.105 0.104 0.174 0.096 0.159 0.134 0.228], Final Value = $5938161.13, Sharpe Ratio = 1.09
#
#
# Simulation Run = 127
# Weights = [0.19  0.087 0.153 0.194 0.153 0.118 0.106], Final Value = $5079398.66, Sharpe Ratio = 1.02
#
#
# Simulation Run = 128
# Weights = [0.11  0.053 0.085 0.209 0.156 0.204 0.183], Final Value = $6374751.08, Sharpe Ratio = 1.10
#
#
# Simulation Run = 129
# Weights = [0.236 0.135 0.056 0.022 0.174 0.152 0.225], Final Value = $6428823.60, Sharpe Ratio = 1.14
#
#
# Simulation Run = 130
# Weights = [0.011 0.316 0.12  0.062 0.025 0.278 0.188], Final Value = $6654590.04, Sharpe Ratio = 1.04
#
#
# Simulation Run = 131
# Weights = [0.233 0.243 0.26  0.092 0.087 0.065 0.018], Final Value = $3829617.60, Sharpe Ratio = 0.87
#
#
# Simulation Run = 132
# Weights = [0.025 0.197 0.125 0.185 0.189 0.165 0.115], Final Value = $5222208.99, Sharpe Ratio = 0.98
#
#
# Simulation Run = 133
# Weights = [0.119 0.102 0.076 0.218 0.235 0.097 0.153], Final Value = $5105265.66, Sharpe Ratio = 1.02
#
#
# Simulation Run = 134
# Weights = [0.215 0.167 0.058 0.26  0.083 0.085 0.132], Final Value = $4825461.12, Sharpe Ratio = 0.98
#
#
# Simulation Run = 135
# Weights = [0.169 0.225 0.2   0.028 0.05  0.083 0.245], Final Value = $5481096.87, Sharpe Ratio = 1.04
#
#
# Simulation Run = 136
# Weights = [0.125 0.193 0.156 0.071 0.213 0.099 0.144], Final Value = $5021754.18, Sharpe Ratio = 1.02
#
#
# Simulation Run = 137
# Weights = [0.263 0.089 0.181 0.253 0.043 0.051 0.119], Final Value = $4501100.68, Sharpe Ratio = 0.97
#
#
# Simulation Run = 138
# Weights = [0.095 0.006 0.139 0.252 0.114 0.248 0.146], Final Value = $6522266.46, Sharpe Ratio = 1.10
#
#
# Simulation Run = 139
# Weights = [0.16  0.211 0.203 0.134 0.133 0.035 0.124], Final Value = $4160832.39, Sharpe Ratio = 0.93
#
#
# Simulation Run = 140
# Weights = [0.02  0.33  0.288 0.095 0.081 0.147 0.04 ], Final Value = $4278095.09, Sharpe Ratio = 0.85
#
#
# Simulation Run = 141
# Weights = [0.152 0.103 0.141 0.18  0.149 0.177 0.097], Final Value = $5542897.73, Sharpe Ratio = 1.04
#
#
# Simulation Run = 142
# Weights = [0.204 0.028 0.052 0.104 0.183 0.24  0.189], Final Value = $7094395.65, Sharpe Ratio = 1.18
#
#
# Simulation Run = 143
# Weights = [0.189 0.106 0.224 0.153 0.158 0.    0.169], Final Value = $4286621.34, Sharpe Ratio = 0.97
#
#
# Simulation Run = 144
# Weights = [0.16  0.082 0.05  0.18  0.289 0.221 0.018], Final Value = $5628584.82, Sharpe Ratio = 1.04
#
#
# Simulation Run = 145
# Weights = [0.239 0.066 0.066 0.216 0.224 0.051 0.139], Final Value = $4819086.65, Sharpe Ratio = 1.03
#
#
# Simulation Run = 146
# Weights = [0.231 0.012 0.209 0.159 0.142 0.189 0.058], Final Value = $5635082.04, Sharpe Ratio = 1.07
#
#
# Simulation Run = 147
# Weights = [0.145 0.269 0.167 0.082 0.016 0.227 0.094], Final Value = $5780607.24, Sharpe Ratio = 1.02
#
#
# Simulation Run = 148
# Weights = [0.103 0.233 0.156 0.093 0.052 0.135 0.226], Final Value = $5725839.97, Sharpe Ratio = 1.03
#
#
# Simulation Run = 149
# Weights = [0.219 0.069 0.202 0.151 0.027 0.145 0.187], Final Value = $5890493.70, Sharpe Ratio = 1.09
#
#
# Simulation Run = 150
# Weights = [0.082 0.116 0.049 0.01  0.234 0.293 0.215], Final Value = $7577949.65, Sharpe Ratio = 1.18
#
#
# Simulation Run = 151
# Weights = [0.046 0.2   0.174 0.066 0.114 0.201 0.199], Final Value = $6192590.90, Sharpe Ratio = 1.07
#
#
# Simulation Run = 152
# Weights = [0.019 0.213 0.061 0.207 0.16  0.22  0.12 ], Final Value = $5770843.14, Sharpe Ratio = 1.01
#
#
# Simulation Run = 153
# Weights = [0.077 0.188 0.125 0.181 0.206 0.193 0.029], Final Value = $5047790.43, Sharpe Ratio = 0.96
#
#
# Simulation Run = 154
# Weights = [0.074 0.218 0.287 0.095 0.122 0.162 0.041], Final Value = $4703478.34, Sharpe Ratio = 0.93
#
#
# Simulation Run = 155
# Weights = [0.098 0.177 0.157 0.161 0.16  0.136 0.111], Final Value = $5043179.42, Sharpe Ratio = 0.99
#
#
# Simulation Run = 156
# Weights = [0.042 0.216 0.296 0.187 0.05  0.174 0.035], Final Value = $4609215.22, Sharpe Ratio = 0.89
#
#
# Simulation Run = 157
# Weights = [0.338 0.057 0.011 0.259 0.09  0.133 0.112], Final Value = $5559984.86, Sharpe Ratio = 1.07
#
#
# Simulation Run = 158
# Weights = [0.017 0.211 0.037 0.19  0.194 0.15  0.202], Final Value = $5660822.42, Sharpe Ratio = 1.02
#
#
# Simulation Run = 159
# Weights = [0.01  0.096 0.039 0.208 0.122 0.375 0.149], Final Value = $7633524.85, Sharpe Ratio = 1.12
#
#
# Simulation Run = 160
# Weights = [0.126 0.128 0.056 0.081 0.179 0.205 0.224], Final Value = $6723641.11, Sharpe Ratio = 1.13
#
#
# Simulation Run = 161
# Weights = [0.095 0.206 0.088 0.15  0.026 0.19  0.244], Final Value = $6387137.93, Sharpe Ratio = 1.07
#
#
# Simulation Run = 162
# Weights = [0.099 0.209 0.058 0.022 0.222 0.175 0.215], Final Value = $6285588.06, Sharpe Ratio = 1.10
#
#
# Simulation Run = 163
# Weights = [0.104 0.187 0.236 0.043 0.06  0.319 0.05 ], Final Value = $6458745.89, Sharpe Ratio = 1.05
#
#
# Simulation Run = 164
# Weights = [0.235 0.087 0.071 0.141 0.035 0.233 0.198], Final Value = $6936984.50, Sharpe Ratio = 1.15
#
#
# Simulation Run = 165
# Weights = [0.013 0.272 0.2   0.376 0.105 0.024 0.009], Final Value = $2750026.51, Sharpe Ratio = 0.67
#
#
# Simulation Run = 166
# Weights = [0.245 0.005 0.117 0.179 0.207 0.206 0.042], Final Value = $5801412.16, Sharpe Ratio = 1.08
#
#
# Simulation Run = 167
# Weights = [0.049 0.292 0.217 0.163 0.227 0.005 0.047], Final Value = $3077258.67, Sharpe Ratio = 0.77
#
#
# Simulation Run = 168
# Weights = [0.2   0.133 0.269 0.103 0.131 0.077 0.088], Final Value = $4503325.01, Sharpe Ratio = 0.98
#
#
# Simulation Run = 169
# Weights = [0.154 0.207 0.104 0.111 0.096 0.137 0.191], Final Value = $5672249.55, Sharpe Ratio = 1.05
#
#
# Simulation Run = 170
# Weights = [0.02  0.108 0.162 0.095 0.143 0.168 0.304], Final Value = $6618083.09, Sharpe Ratio = 1.10
#
#
# Simulation Run = 171
# Weights = [0.067 0.211 0.151 0.157 0.132 0.17  0.112], Final Value = $5281927.96, Sharpe Ratio = 0.99
#
#
# Simulation Run = 172
# Weights = [0.367 0.099 0.123 0.031 0.054 0.108 0.218], Final Value = $6105990.39, Sharpe Ratio = 1.14
#
#
# Simulation Run = 173
# Weights = [0.157 0.101 0.082 0.228 0.136 0.258 0.039], Final Value = $5955249.51, Sharpe Ratio = 1.03
#
#
# Simulation Run = 174
# Weights = [0.233 0.089 0.162 0.128 0.231 0.019 0.138], Final Value = $4471085.40, Sharpe Ratio = 1.01
#
#
# Simulation Run = 175
# Weights = [0.145 0.06  0.198 0.162 0.19  0.055 0.19 ], Final Value = $4984604.65, Sharpe Ratio = 1.03
#
#
# Simulation Run = 176
# Weights = [0.113 0.071 0.267 0.154 0.21  0.143 0.043], Final Value = $4801243.62, Sharpe Ratio = 0.98
#
#
# Simulation Run = 177
# Weights = [0.21  0.296 0.038 0.018 0.083 0.207 0.148], Final Value = $6181035.94, Sharpe Ratio = 1.07
#
#
# Simulation Run = 178
# Weights = [0.106 0.036 0.208 0.094 0.21  0.226 0.121], Final Value = $6254076.75, Sharpe Ratio = 1.11
#
#
# Simulation Run = 179
# Weights = [0.035 0.181 0.141 0.148 0.139 0.182 0.175], Final Value = $5810541.68, Sharpe Ratio = 1.04
#
#
# Simulation Run = 180
# Weights = [0.029 0.118 0.137 0.23  0.132 0.248 0.106], Final Value = $6022198.18, Sharpe Ratio = 1.03
#
#
# Simulation Run = 181
# Weights = [0.158 0.27  0.054 0.199 0.09  0.159 0.071], Final Value = $4976396.98, Sharpe Ratio = 0.95
#
#
# Simulation Run = 182
# Weights = [0.228 0.104 0.165 0.139 0.202 0.117 0.045], Final Value = $4778479.58, Sharpe Ratio = 1.00
#
#
# Simulation Run = 183
# Weights = [0.034 0.218 0.029 0.044 0.376 0.226 0.074], Final Value = $5823264.55, Sharpe Ratio = 1.04
#
#
# Simulation Run = 184
# Weights = [0.175 0.093 0.164 0.165 0.1   0.15  0.153], Final Value = $5658063.24, Sharpe Ratio = 1.07
#
#
# Simulation Run = 185
# Weights = [0.117 0.231 0.236 0.173 0.026 0.069 0.149], Final Value = $4454354.55, Sharpe Ratio = 0.93
#
#
# Simulation Run = 186
# Weights = [0.122 0.286 0.124 0.081 0.088 0.261 0.037], Final Value = $5752763.63, Sharpe Ratio = 0.99
#
#
# Simulation Run = 187
# Weights = [0.191 0.098 0.228 0.124 0.271 0.01  0.079], Final Value = $3893091.30, Sharpe Ratio = 0.94
#
#
# Simulation Run = 188
# Weights = [0.195 0.177 0.083 0.052 0.167 0.199 0.126], Final Value = $6079912.79, Sharpe Ratio = 1.10
#
#
# Simulation Run = 189
# Weights = [0.375 0.271 0.036 0.138 0.115 0.056 0.008], Final Value = $3995660.37, Sharpe Ratio = 0.90
#
#
# Simulation Run = 190
# Weights = [0.126 0.198 0.068 0.118 0.175 0.084 0.23 ], Final Value = $5430588.78, Sharpe Ratio = 1.04
#
#
# Simulation Run = 191
# Weights = [0.184 0.193 0.163 0.072 0.171 0.139 0.077], Final Value = $5058865.92, Sharpe Ratio = 1.01
#
#
# Simulation Run = 192
# Weights = [0.147 0.228 0.171 0.203 0.138 0.048 0.064], Final Value = $3820834.37, Sharpe Ratio = 0.87
#
#
# Simulation Run = 193
# Weights = [0.021 0.406 0.214 0.065 0.051 0.207 0.036], Final Value = $4813243.80, Sharpe Ratio = 0.87
#
#
# Simulation Run = 194
# Weights = [0.127 0.05  0.026 0.222 0.196 0.121 0.259], Final Value = $6122784.58, Sharpe Ratio = 1.10
#
#
# Simulation Run = 195
# Weights = [0.082 0.18  0.065 0.192 0.116 0.214 0.15 ], Final Value = $6055078.19, Sharpe Ratio = 1.05
#
#
# Simulation Run = 196
# Weights = [0.245 0.163 0.04  0.063 0.032 0.216 0.241], Final Value = $7054904.46, Sharpe Ratio = 1.15
#
#
# Simulation Run = 197
# Weights = [0.121 0.099 0.09  0.143 0.262 0.103 0.182], Final Value = $5434169.90, Sharpe Ratio = 1.07
#
#
# Simulation Run = 198
# Weights = [0.217 0.247 0.336 0.046 0.002 0.121 0.03 ], Final Value = $4387438.93, Sharpe Ratio = 0.91
#
#
# Simulation Run = 199
# Weights = [0.165 0.157 0.164 0.127 0.142 0.083 0.162], Final Value = $5007769.23, Sharpe Ratio = 1.02
#
#
# Simulation Run = 200
# Weights = [0.182 0.05  0.241 0.3   0.133 0.058 0.035], Final Value = $3895840.88, Sharpe Ratio = 0.88
#
#
# Simulation Run = 201
# Weights = [0.109 0.075 0.421 0.04  0.156 0.11  0.089], Final Value = $4736456.98, Sharpe Ratio = 0.98
#
#
# Simulation Run = 202
# Weights = [0.193 0.242 0.285 0.04  0.107 0.087 0.046], Final Value = $4199673.50, Sharpe Ratio = 0.91
#
#
# Simulation Run = 203
# Weights = [0.018 0.178 0.298 0.326 0.042 0.136 0.002], Final Value = $3900413.21, Sharpe Ratio = 0.79
#
#
# Simulation Run = 204
# Weights = [0.178 0.141 0.243 0.182 0.062 0.134 0.059], Final Value = $4749480.24, Sharpe Ratio = 0.96
#
#
# Simulation Run = 205
# Weights = [0.257 0.101 0.037 0.116 0.228 0.088 0.173], Final Value = $5496279.69, Sharpe Ratio = 1.09
#
#
# Simulation Run = 206
# Weights = [0.129 0.19  0.168 0.029 0.141 0.185 0.158], Final Value = $5971673.42, Sharpe Ratio = 1.08
#
#
# Simulation Run = 207
# Weights = [0.061 0.145 0.111 0.149 0.198 0.195 0.141], Final Value = $5866075.36, Sharpe Ratio = 1.06
#
#
# Simulation Run = 208
# Weights = [0.063 0.124 0.126 0.185 0.17  0.201 0.131], Final Value = $5830535.85, Sharpe Ratio = 1.05
#
#
# Simulation Run = 209
# Weights = [0.295 0.002 0.092 0.348 0.087 0.054 0.122], Final Value = $4709169.82, Sharpe Ratio = 0.99
#
#
# Simulation Run = 210
# Weights = [0.063 0.161 0.256 0.085 0.112 0.127 0.195], Final Value = $5442915.41, Sharpe Ratio = 1.03
#
#
# Simulation Run = 211
# Weights = [0.034 0.162 0.436 0.006 0.152 0.158 0.052], Final Value = $4746185.18, Sharpe Ratio = 0.94
#
#
# Simulation Run = 212
# Weights = [0.206 0.128 0.096 0.111 0.138 0.155 0.166], Final Value = $5912207.92, Sharpe Ratio = 1.10
#
#
# Simulation Run = 213
# Weights = [0.293 0.074 0.22  0.001 0.276 0.113 0.022], Final Value = $4869004.66, Sharpe Ratio = 1.03
#
#
# Simulation Run = 214
# Weights = [0.135 0.129 0.252 0.215 0.009 0.234 0.025], Final Value = $5401108.25, Sharpe Ratio = 0.97
#
#
# Simulation Run = 215
# Weights = [0.18  0.106 0.128 0.075 0.208 0.228 0.075], Final Value = $6081225.39, Sharpe Ratio = 1.10
#
#
# Simulation Run = 216
# Weights = [0.08  0.358 0.131 0.057 0.108 0.211 0.055], Final Value = $5220728.99, Sharpe Ratio = 0.94
#
#
# Simulation Run = 217
# Weights = [0.205 0.132 0.05  0.05  0.221 0.218 0.124], Final Value = $6380808.39, Sharpe Ratio = 1.13
#
#
# Simulation Run = 218
# Weights = [0.009 0.    0.275 0.247 0.26  0.105 0.104], Final Value = $4678047.23, Sharpe Ratio = 0.96
#
#
# Simulation Run = 219
# Weights = [0.223 0.059 0.258 0.29  0.136 0.023 0.012], Final Value = $3454272.54, Sharpe Ratio = 0.83
#
#
# Simulation Run = 220
# Weights = [0.231 0.068 0.001 0.033 0.253 0.172 0.242], Final Value = $6882293.88, Sharpe Ratio = 1.18
#
#
# Simulation Run = 221
# Weights = [0.    0.457 0.054 0.008 0.161 0.03  0.29 ], Final Value = $4814973.49, Sharpe Ratio = 0.91
#
#
# Simulation Run = 222
# Weights = [0.125 0.079 0.161 0.137 0.17  0.194 0.135], Final Value = $5972174.56, Sharpe Ratio = 1.09
#
#
# Simulation Run = 223
# Weights = [0.071 0.299 0.041 0.039 0.013 0.229 0.308], Final Value = $7146388.29, Sharpe Ratio = 1.08
#
#
# Simulation Run = 224
# Weights = [0.139 0.027 0.102 0.139 0.258 0.065 0.269], Final Value = $5751967.40, Sharpe Ratio = 1.10
#
#
# Simulation Run = 225
# Weights = [0.19  0.183 0.211 0.106 0.192 0.04  0.078], Final Value = $4053260.58, Sharpe Ratio = 0.93
#
#
# Simulation Run = 226
# Weights = [0.053 0.068 0.043 0.195 0.209 0.24  0.191], Final Value = $6734244.27, Sharpe Ratio = 1.12
#
#
# Simulation Run = 227
# Weights = [0.107 0.115 0.255 0.227 0.252 0.023 0.02 ], Final Value = $3351964.52, Sharpe Ratio = 0.82
#
#
# Simulation Run = 228
# Weights = [0.22  0.17  0.224 0.099 0.005 0.016 0.266], Final Value = $5010081.50, Sharpe Ratio = 1.01
#
#
# Simulation Run = 229
# Weights = [0.275 0.036 0.108 0.025 0.018 0.283 0.254], Final Value = $8005737.31, Sharpe Ratio = 1.22
#
#
# Simulation Run = 230
# Weights = [0.038 0.117 0.24  0.078 0.046 0.118 0.363], Final Value = $6442242.41, Sharpe Ratio = 1.06
#
#
# Simulation Run = 231
# Weights = [0.159 0.013 0.004 0.357 0.17  0.198 0.099], Final Value = $5832478.11, Sharpe Ratio = 1.04
#
#
# Simulation Run = 232
# Weights = [0.227 0.199 0.182 0.012 0.19  0.141 0.049], Final Value = $5007863.07, Sharpe Ratio = 1.01
#
#
# Simulation Run = 233
# Weights = [0.193 0.032 0.209 0.012 0.196 0.131 0.227], Final Value = $6219358.21, Sharpe Ratio = 1.14
#
#
# Simulation Run = 234
# Weights = [0.027 0.262 0.013 0.202 0.004 0.232 0.259], Final Value = $6698999.33, Sharpe Ratio = 1.05
#
#
# Simulation Run = 235
# Weights = [0.214 0.212 0.156 0.058 0.152 0.042 0.166], Final Value = $4709964.87, Sharpe Ratio = 1.00
#
#
# Simulation Run = 236
# Weights = [0.213 0.023 0.139 0.083 0.236 0.1   0.207], Final Value = $5833469.73, Sharpe Ratio = 1.13
#
#
# Simulation Run = 237
# Weights = [0.02  0.031 0.242 0.061 0.336 0.162 0.148], Final Value = $5735299.91, Sharpe Ratio = 1.08
#
#
# Simulation Run = 238
# Weights = [0.064 0.197 0.138 0.059 0.187 0.11  0.246], Final Value = $5693259.56, Sharpe Ratio = 1.05
#
#
# Simulation Run = 239
# Weights = [0.45  0.069 0.308 0.077 0.027 0.049 0.021], Final Value = $4246075.55, Sharpe Ratio = 0.96
#
#
# Simulation Run = 240
# Weights = [0.004 0.013 0.141 0.188 0.33  0.035 0.29 ], Final Value = $5341793.16, Sharpe Ratio = 1.04
#
#
# Simulation Run = 241
# Weights = [0.065 0.253 0.08  0.039 0.218 0.235 0.11 ], Final Value = $6045367.53, Sharpe Ratio = 1.05
#
#
# Simulation Run = 242
# Weights = [0.085 0.335 0.053 0.329 0.054 0.085 0.058], Final Value = $3826419.47, Sharpe Ratio = 0.80
#
#
# Simulation Run = 243
# Weights = [0.143 0.09  0.293 0.167 0.072 0.073 0.162], Final Value = $4802070.65, Sharpe Ratio = 0.99
#
#
# Simulation Run = 244
# Weights = [0.137 0.27  0.266 0.021 0.042 0.171 0.092], Final Value = $5200666.08, Sharpe Ratio = 0.98
#
#
# Simulation Run = 245
# Weights = [0.095 0.011 0.062 0.201 0.225 0.141 0.266], Final Value = $6383250.61, Sharpe Ratio = 1.12
#
#
# Simulation Run = 246
# Weights = [0.117 0.204 0.113 0.254 0.105 0.118 0.089], Final Value = $4631365.98, Sharpe Ratio = 0.93
#
#
# Simulation Run = 247
# Weights = [0.177 0.176 0.071 0.076 0.087 0.185 0.228], Final Value = $6515431.99, Sharpe Ratio = 1.11
#
#
# Simulation Run = 248
# Weights = [0.341 0.079 0.012 0.17  0.107 0.033 0.258], Final Value = $5582082.30, Sharpe Ratio = 1.09
#
#
# Simulation Run = 249
# Weights = [0.206 0.195 0.195 0.048 0.099 0.061 0.196], Final Value = $5057784.35, Sharpe Ratio = 1.03
#
#
# Simulation Run = 250
# Weights = [0.172 0.1   0.057 0.124 0.032 0.333 0.183], Final Value = $7725445.96, Sharpe Ratio = 1.17
#
#
# Simulation Run = 251
# Weights = [0.048 0.093 0.229 0.17  0.029 0.262 0.168], Final Value = $6575066.29, Sharpe Ratio = 1.08
#
#
# Simulation Run = 252
# Weights = [0.135 0.264 0.067 0.053 0.06  0.191 0.23 ], Final Value = $6414108.29, Sharpe Ratio = 1.08
#
#
# Simulation Run = 253
# Weights = [0.116 0.143 0.255 0.167 0.094 0.155 0.07 ], Final Value = $4943504.71, Sharpe Ratio = 0.97
#
#
# Simulation Run = 254
# Weights = [0.189 0.16  0.091 0.092 0.073 0.238 0.156], Final Value = $6579768.73, Sharpe Ratio = 1.12
#
#
# Simulation Run = 255
# Weights = [0.136 0.023 0.092 0.14  0.195 0.193 0.222], Final Value = $6680954.27, Sharpe Ratio = 1.15
#
#
# Simulation Run = 256
# Weights = [0.16  0.181 0.088 0.167 0.106 0.114 0.183], Final Value = $5412715.94, Sharpe Ratio = 1.03
#
#
# Simulation Run = 257
# Weights = [0.106 0.251 0.186 0.081 0.    0.216 0.16 ], Final Value = $6034776.84, Sharpe Ratio = 1.04
#
#
# Simulation Run = 258
# Weights = [0.088 0.073 0.203 0.115 0.178 0.168 0.175], Final Value = $5917763.48, Sharpe Ratio = 1.09
#
#
# Simulation Run = 259
# Weights = [0.094 0.044 0.084 0.243 0.215 0.022 0.299], Final Value = $5309836.40, Sharpe Ratio = 1.03
#
#
# Simulation Run = 260
# Weights = [0.018 0.04  0.276 0.215 0.196 0.108 0.147], Final Value = $4940641.80, Sharpe Ratio = 0.99
#
#
# Simulation Run = 261
# Weights = [0.089 0.223 0.039 0.156 0.094 0.218 0.182], Final Value = $6280003.60, Sharpe Ratio = 1.06
#
#
# Simulation Run = 262
# Weights = [0.09  0.098 0.101 0.192 0.225 0.18  0.113], Final Value = $5629051.79, Sharpe Ratio = 1.05
#
#
# Simulation Run = 263
# Weights = [0.295 0.219 0.081 0.063 0.131 0.187 0.024], Final Value = $5385015.32, Sharpe Ratio = 1.02
#
#
# Simulation Run = 264
# Weights = [0.166 0.24  0.103 0.06  0.139 0.222 0.07 ], Final Value = $5769615.50, Sharpe Ratio = 1.04
#
#
# Simulation Run = 265
# Weights = [0.197 0.086 0.11  0.162 0.131 0.189 0.126], Final Value = $5968750.36, Sharpe Ratio = 1.09
#
#
# Simulation Run = 266
# Weights = [0.056 0.115 0.262 0.178 0.099 0.06  0.23 ], Final Value = $4967899.61, Sharpe Ratio = 0.99
#
#
# Simulation Run = 267
# Weights = [0.091 0.018 0.174 0.239 0.05  0.294 0.134], Final Value = $6827357.78, Sharpe Ratio = 1.10
#
#
# Simulation Run = 268
# Weights = [0.117 0.078 0.039 0.103 0.098 0.274 0.291], Final Value = $7843433.96, Sharpe Ratio = 1.17
#
#
# Simulation Run = 269
# Weights = [0.179 0.192 0.245 0.193 0.019 0.089 0.082], Final Value = $4345595.68, Sharpe Ratio = 0.92
#
#
# Simulation Run = 270
# Weights = [0.32  0.025 0.1   0.364 0.031 0.053 0.106], Final Value = $4558743.70, Sharpe Ratio = 0.96
#
#
# Simulation Run = 271
# Weights = [0.102 0.054 0.167 0.084 0.201 0.202 0.189], Final Value = $6463977.07, Sharpe Ratio = 1.13
#
#
# Simulation Run = 272
# Weights = [0.22  0.232 0.065 0.26  0.148 0.011 0.064], Final Value = $3594107.14, Sharpe Ratio = 0.85
#
#
# Simulation Run = 273
# Weights = [0.037 0.144 0.173 0.069 0.19  0.188 0.199], Final Value = $6154729.50, Sharpe Ratio = 1.08
#
#
# Simulation Run = 274
# Weights = [0.133 0.194 0.306 0.045 0.079 0.008 0.234], Final Value = $4582680.74, Sharpe Ratio = 0.97
#
#
# Simulation Run = 275
# Weights = [0.123 0.165 0.16  0.232 0.126 0.053 0.141], Final Value = $4386810.77, Sharpe Ratio = 0.94
#
#
# Simulation Run = 276
# Weights = [0.099 0.029 0.3   0.09  0.002 0.217 0.262], Final Value = $6923126.36, Sharpe Ratio = 1.13
#
#
# Simulation Run = 277
# Weights = [0.246 0.158 0.039 0.025 0.241 0.089 0.203], Final Value = $5692114.25, Sharpe Ratio = 1.10
#
#
# Simulation Run = 278
# Weights = [0.246 0.208 0.214 0.036 0.101 0.119 0.076], Final Value = $4898045.76, Sharpe Ratio = 1.00
#
#
# Simulation Run = 279
# Weights = [0.193 0.067 0.218 0.013 0.162 0.208 0.138], Final Value = $6335642.24, Sharpe Ratio = 1.14
#
#
# Simulation Run = 280
# Weights = [0.259 0.069 0.008 0.204 0.134 0.213 0.114], Final Value = $6283163.32, Sharpe Ratio = 1.11
#
#
# Simulation Run = 281
# Weights = [0.052 0.155 0.252 0.147 0.035 0.036 0.324], Final Value = $5273512.39, Sharpe Ratio = 0.99
#
#
# Simulation Run = 282
# Weights = [0.253 0.083 0.025 0.082 0.014 0.122 0.421], Final Value = $7391362.84, Sharpe Ratio = 1.13
#
#
# Simulation Run = 283
# Weights = [0.233 0.047 0.264 0.002 0.134 0.267 0.053], Final Value = $6433014.00, Sharpe Ratio = 1.12
#
#
# Simulation Run = 284
# Weights = [0.083 0.31  0.176 0.329 0.009 0.075 0.019], Final Value = $3394491.13, Sharpe Ratio = 0.74
#
#
# Simulation Run = 285
# Weights = [0.211 0.033 0.297 0.171 0.063 0.078 0.148], Final Value = $4949443.24, Sharpe Ratio = 1.02
#
#
# Simulation Run = 286
# Weights = [0.076 0.038 0.221 0.218 0.24  0.194 0.013], Final Value = $5083742.35, Sharpe Ratio = 0.97
#
#
# Simulation Run = 287
# Weights = [0.015 0.165 0.032 0.23  0.187 0.104 0.267], Final Value = $5649283.98, Sharpe Ratio = 1.02
#
#
# Simulation Run = 288
# Weights = [0.229 0.217 0.202 0.197 0.058 0.066 0.031], Final Value = $3883251.23, Sharpe Ratio = 0.87
#
#
# Simulation Run = 289
# Weights = [0.266 0.257 0.056 0.085 0.142 0.176 0.018], Final Value = $5135553.19, Sharpe Ratio = 0.99
#
#
# Simulation Run = 290
# Weights = [0.239 0.09  0.217 0.256 0.007 0.144 0.046], Final Value = $4855921.09, Sharpe Ratio = 0.96
#
#
# Simulation Run = 291
# Weights = [0.143 0.105 0.108 0.167 0.188 0.125 0.164], Final Value = $5491675.06, Sharpe Ratio = 1.06
#
#
# Simulation Run = 292
# Weights = [0.155 0.13  0.069 0.199 0.081 0.284 0.082], Final Value = $6462163.84, Sharpe Ratio = 1.07
#
#
# Simulation Run = 293
# Weights = [0.211 0.139 0.022 0.201 0.188 0.21  0.029], Final Value = $5551542.42, Sharpe Ratio = 1.02
#
#
# Simulation Run = 294
# Weights = [0.223 0.213 0.193 0.019 0.023 0.239 0.09 ], Final Value = $6123672.18, Sharpe Ratio = 1.07
#
#
# Simulation Run = 295
# Weights = [0.159 0.105 0.166 0.159 0.253 0.09  0.067], Final Value = $4552583.57, Sharpe Ratio = 0.98
#
#
# Simulation Run = 296
# Weights = [0.028 0.202 0.077 0.272 0.189 0.174 0.058], Final Value = $4886083.27, Sharpe Ratio = 0.92
#
#
# Simulation Run = 297
# Weights = [0.106 0.372 0.089 0.02  0.343 0.014 0.056], Final Value = $3490027.58, Sharpe Ratio = 0.83
#
#
# Simulation Run = 298
# Weights = [0.217 0.157 0.195 0.175 0.132 0.065 0.061], Final Value = $4185366.60, Sharpe Ratio = 0.93
#
#
# Simulation Run = 299
# Weights = [0.257 0.114 0.125 0.002 0.194 0.173 0.136], Final Value = $6102976.28, Sharpe Ratio = 1.13
#
#
# Simulation Run = 300
# Weights = [0.049 0.15  0.164 0.151 0.12  0.289 0.078], Final Value = $6280226.45, Sharpe Ratio = 1.05
#
#
# Simulation Run = 301
# Weights = [0.257 0.178 0.1   0.195 0.06  0.08  0.13 ], Final Value = $4838908.85, Sharpe Ratio = 0.99
#
#
# Simulation Run = 302
# Weights = [0.159 0.241 0.153 0.1   0.122 0.147 0.078], Final Value = $4991920.84, Sharpe Ratio = 0.98
#
#
# Simulation Run = 303
# Weights = [0.207 0.064 0.099 0.042 0.179 0.216 0.193], Final Value = $6858063.69, Sharpe Ratio = 1.17
#
#
# Simulation Run = 304
# Weights = [0.205 0.176 0.189 0.017 0.144 0.259 0.01 ], Final Value = $5890980.39, Sharpe Ratio = 1.04
#
#
# Simulation Run = 305
# Weights = [0.085 0.263 0.131 0.103 0.197 0.017 0.203], Final Value = $4411804.36, Sharpe Ratio = 0.95
#
#
# Simulation Run = 306
# Weights = [0.133 0.182 0.036 0.305 0.043 0.089 0.212], Final Value = $5177674.63, Sharpe Ratio = 0.98
#
#
# Simulation Run = 307
# Weights = [0.17  0.118 0.184 0.017 0.132 0.139 0.241], Final Value = $6217157.66, Sharpe Ratio = 1.12
#
#
# Simulation Run = 308
# Weights = [0.021 0.162 0.151 0.077 0.255 0.265 0.068], Final Value = $6066122.05, Sharpe Ratio = 1.05
#
#
# Simulation Run = 309
# Weights = [0.12  0.31  0.052 0.067 0.053 0.18  0.218], Final Value = $6129114.12, Sharpe Ratio = 1.05
#
#
# Simulation Run = 310
# Weights = [0.122 0.209 0.084 0.22  0.194 0.159 0.013], Final Value = $4636451.28, Sharpe Ratio = 0.91
#
#
# Simulation Run = 311
# Weights = [0.22  0.065 0.016 0.123 0.193 0.31  0.073], Final Value = $7017785.40, Sharpe Ratio = 1.15
#
#
# Simulation Run = 312
# Weights = [0.163 0.169 0.163 0.112 0.168 0.086 0.14 ], Final Value = $4897485.90, Sharpe Ratio = 1.01
#
#
# Simulation Run = 313
# Weights = [0.159 0.08  0.116 0.167 0.117 0.167 0.194], Final Value = $6122741.12, Sharpe Ratio = 1.10
#
#
# Simulation Run = 314
# Weights = [0.178 0.071 0.222 0.137 0.154 0.221 0.016], Final Value = $5529842.74, Sharpe Ratio = 1.02
#
#
# Simulation Run = 315
# Weights = [0.08  0.372 0.015 0.039 0.255 0.095 0.144], Final Value = $4802623.57, Sharpe Ratio = 0.95
#
#
# Simulation Run = 316
# Weights = [0.188 0.164 0.059 0.192 0.19  0.108 0.098], Final Value = $4905895.95, Sharpe Ratio = 1.00
#
#
# Simulation Run = 317
# Weights = [0.097 0.236 0.014 0.149 0.064 0.186 0.255], Final Value = $6442037.52, Sharpe Ratio = 1.07
#
#
# Simulation Run = 318
# Weights = [0.157 0.166 0.178 0.136 0.004 0.176 0.184], Final Value = $5953940.97, Sharpe Ratio = 1.06
#
#
# Simulation Run = 319
# Weights = [0.183 0.206 0.012 0.028 0.154 0.23  0.187], Final Value = $6779102.04, Sharpe Ratio = 1.13
#
#
# Simulation Run = 320
# Weights = [0.272 0.086 0.003 0.109 0.074 0.201 0.255], Final Value = $7138803.85, Sharpe Ratio = 1.17
#
#
# Simulation Run = 321
# Weights = [0.142 0.065 0.021 0.108 0.231 0.213 0.22 ], Final Value = $6917911.74, Sharpe Ratio = 1.16
#
#
# Simulation Run = 322
# Weights = [0.204 0.283 0.115 0.093 0.058 0.221 0.026], Final Value = $5401230.42, Sharpe Ratio = 0.98
#
#
# Simulation Run = 323
# Weights = [0.127 0.028 0.1   0.222 0.216 0.111 0.196], Final Value = $5607248.69, Sharpe Ratio = 1.07
#
#
# Simulation Run = 324
# Weights = [0.059 0.085 0.223 0.229 0.105 0.229 0.07 ], Final Value = $5622446.76, Sharpe Ratio = 1.00
#
#
# Simulation Run = 325
# Weights = [0.178 0.031 0.027 0.053 0.239 0.238 0.234], Final Value = $7414509.11, Sharpe Ratio = 1.20
#
#
# Simulation Run = 326
# Weights = [0.163 0.183 0.121 0.146 0.188 0.155 0.044], Final Value = $4946954.52, Sharpe Ratio = 0.98
#
#
# Simulation Run = 327
# Weights = [0.184 0.055 0.005 0.187 0.045 0.236 0.289], Final Value = $7515051.80, Sharpe Ratio = 1.16
#
#
# Simulation Run = 328
# Weights = [0.214 0.094 0.121 0.151 0.154 0.2   0.067], Final Value = $5728928.10, Sharpe Ratio = 1.06
#
#
# Simulation Run = 329
# Weights = [0.15  0.223 0.1   0.24  0.02  0.116 0.152], Final Value = $5026997.65, Sharpe Ratio = 0.97
#
#
# Simulation Run = 330
# Weights = [0.039 0.216 0.252 0.004 0.251 0.103 0.135], Final Value = $4842393.84, Sharpe Ratio = 0.98
#
#
# Simulation Run = 331
# Weights = [0.277 0.007 0.044 0.181 0.058 0.303 0.131], Final Value = $7370846.01, Sharpe Ratio = 1.17
#
#
# Simulation Run = 332
# Weights = [0.125 0.14  0.134 0.08  0.159 0.178 0.184], Final Value = $6110482.72, Sharpe Ratio = 1.10
#
#
# Simulation Run = 333
# Weights = [0.074 0.278 0.056 0.15  0.255 0.145 0.041], Final Value = $4618960.31, Sharpe Ratio = 0.92
#
#
# Simulation Run = 334
# Weights = [0.142 0.169 0.124 0.152 0.197 0.059 0.156], Final Value = $4705231.76, Sharpe Ratio = 0.99
#
#
# Simulation Run = 335
# Weights = [0.24  0.169 0.053 0.095 0.087 0.118 0.239], Final Value = $6037588.96, Sharpe Ratio = 1.10
#
#
# Simulation Run = 336
# Weights = [0.119 0.213 0.158 0.054 0.171 0.177 0.107], Final Value = $5511448.88, Sharpe Ratio = 1.03
#
#
# Simulation Run = 337
# Weights = [0.081 0.175 0.189 0.183 0.187 0.059 0.126], Final Value = $4327929.87, Sharpe Ratio = 0.94
#
#
# Simulation Run = 338
# Weights = [0.06  0.04  0.093 0.248 0.148 0.273 0.138], Final Value = $6652950.43, Sharpe Ratio = 1.09
#
#
# Simulation Run = 339
# Weights = [0.005 0.325 0.199 0.076 0.093 0.004 0.298], Final Value = $4609970.46, Sharpe Ratio = 0.91
#
#
# Simulation Run = 340
# Weights = [0.046 0.162 0.195 0.178 0.212 0.146 0.061], Final Value = $4737304.65, Sharpe Ratio = 0.95
#
#
# Simulation Run = 341
# Weights = [0.143 0.106 0.226 0.241 0.09  0.159 0.036], Final Value = $4799207.92, Sharpe Ratio = 0.94
#
#
# Simulation Run = 342
# Weights = [0.224 0.132 0.101 0.216 0.028 0.107 0.192], Final Value = $5471674.11, Sharpe Ratio = 1.04
#
#
# Simulation Run = 343
# Weights = [0.221 0.118 0.003 0.112 0.176 0.212 0.158], Final Value = $6539603.93, Sharpe Ratio = 1.14
#
#
# Simulation Run = 344
# Weights = [0.041 0.082 0.12  0.119 0.111 0.216 0.31 ], Final Value = $7199152.90, Sharpe Ratio = 1.13
#
#
# Simulation Run = 345
# Weights = [0.153 0.195 0.094 0.284 0.169 0.032 0.072], Final Value = $3762980.16, Sharpe Ratio = 0.86
#
#
# Simulation Run = 346
# Weights = [0.021 0.171 0.153 0.182 0.187 0.064 0.223], Final Value = $4928626.43, Sharpe Ratio = 0.98
#
#
# Simulation Run = 347
# Weights = [0.207 0.194 0.177 0.107 0.049 0.201 0.064], Final Value = $5522101.92, Sharpe Ratio = 1.02
#
#
# Simulation Run = 348
# Weights = [0.025 0.267 0.075 0.107 0.211 0.214 0.102], Final Value = $5638900.25, Sharpe Ratio = 1.00
#
#
# Simulation Run = 349
# Weights = [0.112 0.155 0.206 0.105 0.074 0.113 0.235], Final Value = $5647702.50, Sharpe Ratio = 1.05
#
#
# Simulation Run = 350
# Weights = [0.103 0.186 0.08  0.155 0.058 0.216 0.202], Final Value = $6431642.73, Sharpe Ratio = 1.08
#
#
# Simulation Run = 351
# Weights = [0.236 0.036 0.303 0.003 0.132 0.225 0.067], Final Value = $6089900.68, Sharpe Ratio = 1.11
#
#
# Simulation Run = 352
# Weights = [0.121 0.236 0.054 0.257 0.023 0.236 0.073], Final Value = $5656776.04, Sharpe Ratio = 0.98
#
#
# Simulation Run = 353
# Weights = [0.239 0.251 0.12  0.029 0.184 0.104 0.072], Final Value = $4759162.74, Sharpe Ratio = 0.99
#
#
# Simulation Run = 354
# Weights = [0.022 0.108 0.169 0.246 0.189 0.205 0.061], Final Value = $5297962.94, Sharpe Ratio = 0.97
#
#
# Simulation Run = 355
# Weights = [0.004 0.2   0.067 0.194 0.223 0.166 0.146], Final Value = $5436940.68, Sharpe Ratio = 1.00
#
#
# Simulation Run = 356
# Weights = [0.149 0.141 0.085 0.27  0.178 0.158 0.02 ], Final Value = $4757349.49, Sharpe Ratio = 0.93
#
#
# Simulation Run = 357
# Weights = [0.101 0.135 0.236 0.04  0.234 0.16  0.095], Final Value = $5328308.39, Sharpe Ratio = 1.04
#
#
# Simulation Run = 358
# Weights = [0.153 0.08  0.236 0.104 0.041 0.245 0.141], Final Value = $6482469.23, Sharpe Ratio = 1.11
#
#
# Simulation Run = 359
# Weights = [0.088 0.203 0.028 0.056 0.209 0.157 0.259], Final Value = $6362221.08, Sharpe Ratio = 1.09
#
#
# Simulation Run = 360
# Weights = [0.305 0.308 0.151 0.053 0.035 0.113 0.034], Final Value = $4523628.81, Sharpe Ratio = 0.93
#
#
# Simulation Run = 361
# Weights = [0.279 0.107 0.002 0.041 0.302 0.153 0.116], Final Value = $5927181.05, Sharpe Ratio = 1.13
#
#
# Simulation Run = 362
# Weights = [0.201 0.185 0.058 0.238 0.056 0.197 0.065], Final Value = $5458939.98, Sharpe Ratio = 1.00
#
#
# Simulation Run = 363
# Weights = [0.08  0.226 0.084 0.175 0.23  0.034 0.172], Final Value = $4401939.21, Sharpe Ratio = 0.95
#
#
# Simulation Run = 364
# Weights = [0.162 0.201 0.144 0.086 0.142 0.113 0.152], Final Value = $5224949.82, Sharpe Ratio = 1.03
#
#
# Simulation Run = 365
# Weights = [0.143 0.204 0.191 0.172 0.142 0.06  0.088], Final Value = $4139078.93, Sharpe Ratio = 0.91
#
#
# Simulation Run = 366
# Weights = [0.218 0.091 0.175 0.08  0.119 0.103 0.214], Final Value = $5743822.53, Sharpe Ratio = 1.10
#
#
# Simulation Run = 367
# Weights = [0.093 0.164 0.175 0.228 0.181 0.027 0.132], Final Value = $4050638.54, Sharpe Ratio = 0.91
#
#
# Simulation Run = 368
# Weights = [0.134 0.238 0.043 0.22  0.105 0.026 0.234], Final Value = $4722455.88, Sharpe Ratio = 0.96
#
#
# Simulation Run = 369
# Weights = [0.125 0.243 0.117 0.013 0.112 0.217 0.174], Final Value = $6342570.41, Sharpe Ratio = 1.08
#
#
# Simulation Run = 370
# Weights = [0.152 0.214 0.122 0.138 0.201 0.065 0.107], Final Value = $4417718.42, Sharpe Ratio = 0.96
#
#
# Simulation Run = 371
# Weights = [0.031 0.048 0.102 0.168 0.181 0.209 0.26 ], Final Value = $6838966.95, Sharpe Ratio = 1.12
#
#
# Simulation Run = 372
# Weights = [0.141 0.137 0.085 0.091 0.189 0.125 0.233], Final Value = $5975479.11, Sharpe Ratio = 1.09
#
#
# Simulation Run = 373
# Weights = [0.265 0.05  0.101 0.011 0.145 0.169 0.259], Final Value = $6947364.66, Sharpe Ratio = 1.18
#
#
# Simulation Run = 374
# Weights = [0.17  0.111 0.186 0.069 0.076 0.136 0.252], Final Value = $6197480.98, Sharpe Ratio = 1.10
#
#
# Simulation Run = 375
# Weights = [0.106 0.097 0.167 0.169 0.195 0.121 0.146], Final Value = $5246320.29, Sharpe Ratio = 1.03
#
#
# Simulation Run = 376
# Weights = [0.066 0.204 0.119 0.013 0.141 0.216 0.241], Final Value = $6740766.86, Sharpe Ratio = 1.11
#
#
# Simulation Run = 377
# Weights = [0.127 0.099 0.041 0.178 0.193 0.169 0.194], Final Value = $6138754.46, Sharpe Ratio = 1.10
#
#
# Simulation Run = 378
# Weights = [0.169 0.143 0.064 0.093 0.135 0.164 0.232], Final Value = $6380396.57, Sharpe Ratio = 1.12
#
#
# Simulation Run = 379
# Weights = [0.155 0.301 0.036 0.134 0.119 0.214 0.042], Final Value = $5370239.54, Sharpe Ratio = 0.97
#
#
# Simulation Run = 380
# Weights = [0.14  0.136 0.16  0.166 0.001 0.197 0.2  ], Final Value = $6267863.28, Sharpe Ratio = 1.08
#
#
# Simulation Run = 381
# Weights = [0.231 0.134 0.223 0.183 0.175 0.018 0.035], Final Value = $3609820.85, Sharpe Ratio = 0.88
#
#
# Simulation Run = 382
# Weights = [0.03  0.212 0.233 0.213 0.127 0.049 0.135], Final Value = $4063697.08, Sharpe Ratio = 0.88
#
#
# Simulation Run = 383
# Weights = [0.013 0.169 0.102 0.203 0.165 0.17  0.178], Final Value = $5688831.48, Sharpe Ratio = 1.02
#
#
# Simulation Run = 384
# ...
#
#
# Simulation Run = 872
# Weights = [0.182 0.182 0.145 0.018 0.139 0.092 0.242], Final Value = $5713225.38, Sharpe Ratio = 1.07
#
#
# Simulation Run = 873
# Weights = [0.259 0.17  0.181 0.113 0.048 0.146 0.083], Final Value = $5214511.16, Sharpe Ratio = 1.02
#
#
# Simulation Run = 874
# Weights = [0.247 0.018 0.219 0.048 0.044 0.243 0.182], Final Value = $7033386.74, Sharpe Ratio = 1.18
#
#
# Simulation Run = 875
# Weights = [0.123 0.129 0.168 0.186 0.116 0.179 0.098], Final Value = $5441019.63, Sharpe Ratio = 1.02
#
#
# Simulation Run = 876
# Weights = [0.031 0.182 0.196 0.179 0.159 0.137 0.115], Final Value = $4924212.70, Sharpe Ratio = 0.96
#
#
# Simulation Run = 877
# Weights = [0.261 0.007 0.061 0.241 0.105 0.26  0.064], Final Value = $6441071.17, Sharpe Ratio = 1.10
#
#
# Simulation Run = 878
# Weights = [0.016 0.019 0.111 0.236 0.152 0.234 0.232], Final Value = $6836062.96, Sharpe Ratio = 1.11
#
#
# Simulation Run = 879
# Weights = [0.04  0.068 0.23  0.231 0.106 0.19  0.136], Final Value = $5647590.16, Sharpe Ratio = 1.02
#
#
# Simulation Run = 880
# Weights = [0.167 0.152 0.141 0.086 0.141 0.182 0.131], Final Value = $5847494.46, Sharpe Ratio = 1.08
#
#
# Simulation Run = 881
# Weights = [0.056 0.075 0.055 0.094 0.125 0.278 0.316], Final Value = $7963799.70, Sharpe Ratio = 1.17
#
#
# Simulation Run = 882
# Weights = [0.017 0.162 0.068 0.183 0.215 0.28  0.075], Final Value = $6179921.61, Sharpe Ratio = 1.04
#
#
# Simulation Run = 883
# Weights = [0.101 0.04  0.089 0.119 0.109 0.288 0.253], Final Value = $7718952.49, Sharpe Ratio = 1.18
#
#
# Simulation Run = 884
# Weights = [0.035 0.147 0.029 0.23  0.219 0.12  0.22 ], Final Value = $5574856.00, Sharpe Ratio = 1.03
#
#
# Simulation Run = 885
# Weights = [0.119 0.215 0.247 0.004 0.075 0.2   0.141], Final Value = $5888936.01, Sharpe Ratio = 1.05
#
#
# Simulation Run = 886
# Weights = [0.094 0.112 0.196 0.153 0.181 0.142 0.122], Final Value = $5252719.92, Sharpe Ratio = 1.02
#
#
# Simulation Run = 887
# Weights = [0.213 0.213 0.005 0.187 0.139 0.195 0.049], Final Value = $5433757.15, Sharpe Ratio = 1.01
#
#
# Simulation Run = 888
# Weights = [0.034 0.299 0.041 0.222 0.205 0.014 0.186], Final Value = $4090638.19, Sharpe Ratio = 0.89
#
#
# Simulation Run = 889
# Weights = [0.126 0.212 0.145 0.06  0.136 0.256 0.065], Final Value = $6017070.89, Sharpe Ratio = 1.05
#
#
# Simulation Run = 890
# Weights = [0.058 0.288 0.094 0.02  0.125 0.107 0.309], Final Value = $5972171.71, Sharpe Ratio = 1.03
#
#
# Simulation Run = 891
# Weights = [0.049 0.195 0.104 0.201 0.147 0.178 0.126], Final Value = $5436622.66, Sharpe Ratio = 1.00
#
#
# Simulation Run = 892
# Weights = [0.142 0.046 0.237 0.045 0.091 0.248 0.189], Final Value = $6936468.82, Sharpe Ratio = 1.15
#
#
# Simulation Run = 893
# Weights = [0.162 0.054 0.135 0.193 0.03  0.335 0.09 ], Final Value = $7073127.96, Sharpe Ratio = 1.11
#
#
# Simulation Run = 894
# Weights = [0.11  0.106 0.153 0.068 0.184 0.208 0.172], Final Value = $6365434.44, Sharpe Ratio = 1.12
#
#
# Simulation Run = 895
# Weights = [0.269 0.037 0.184 0.146 0.165 0.111 0.089], Final Value = $5129610.91, Sharpe Ratio = 1.05
#
#
# Simulation Run = 896
# Weights = [0.069 0.064 0.287 0.04  0.073 0.119 0.349], Final Value = $6506147.43, Sharpe Ratio = 1.09
#
#
# Simulation Run = 897
# Weights = [0.086 0.053 0.251 0.108 0.291 0.135 0.077], Final Value = $5008142.14, Sharpe Ratio = 1.02
#
#
# Simulation Run = 898
# Weights = [0.098 0.164 0.157 0.215 0.151 0.12  0.095], Final Value = $4743121.13, Sharpe Ratio = 0.96
#
#
# Simulation Run = 899
# Weights = [0.175 0.037 0.193 0.173 0.18  0.127 0.114], Final Value = $5271773.41, Sharpe Ratio = 1.05
#
#
# Simulation Run = 900
# Weights = [0.2   0.211 0.1   0.155 0.165 0.144 0.025], Final Value = $4732582.57, Sharpe Ratio = 0.95
#
#
# Simulation Run = 901
# Weights = [0.094 0.445 0.034 0.018 0.032 0.054 0.322], Final Value = $5373088.66, Sharpe Ratio = 0.95
#
#
# Simulation Run = 902
# Weights = [0.217 0.246 0.263 0.002 0.    0.072 0.2  ], Final Value = $5089036.10, Sharpe Ratio = 1.01
#
#
# Simulation Run = 903
# Weights = [0.336 0.23  0.204 0.032 0.083 0.007 0.107], Final Value = $4116445.67, Sharpe Ratio = 0.95
#
#
# Simulation Run = 904
# Weights = [0.229 0.192 0.06  0.141 0.157 0.172 0.047], Final Value = $5268755.63, Sharpe Ratio = 1.01
#
#
# Simulation Run = 905
# Weights = [0.127 0.095 0.157 0.13  0.001 0.349 0.141], Final Value = $7457512.99, Sharpe Ratio = 1.13
#
#
# Simulation Run = 906
# Weights = [0.158 0.029 0.092 0.11  0.244 0.027 0.339], Final Value = $5882950.19, Sharpe Ratio = 1.09
#
#
# Simulation Run = 907
# Weights = [0.204 0.169 0.068 0.135 0.139 0.123 0.161], Final Value = $5502021.73, Sharpe Ratio = 1.06
#
#
# Simulation Run = 908
# Weights = [0.079 0.018 0.256 0.126 0.18  0.087 0.254], Final Value = $5643256.31, Sharpe Ratio = 1.07
#
#
# Simulation Run = 909
# Weights = [0.137 0.237 0.183 0.245 0.014 0.105 0.08 ], Final Value = $4348557.88, Sharpe Ratio = 0.89
#
#
# Simulation Run = 910
# Weights = [0.19  0.159 0.173 0.137 0.108 0.123 0.109], Final Value = $5072698.62, Sharpe Ratio = 1.01
#
#
# Simulation Run = 911
# Weights = [0.122 0.005 0.085 0.243 0.215 0.023 0.307], Final Value = $5474123.98, Sharpe Ratio = 1.05
#
#
# Simulation Run = 912
# Weights = [0.018 0.069 0.079 0.308 0.013 0.195 0.319], Final Value = $6833247.36, Sharpe Ratio = 1.07
#
#
# Simulation Run = 913
# Weights = [0.204 0.237 0.078 0.1   0.038 0.224 0.12 ], Final Value = $6114424.09, Sharpe Ratio = 1.06
#
#
# Simulation Run = 914
# Weights = [0.251 0.022 0.173 0.111 0.077 0.191 0.174], Final Value = $6461580.82, Sharpe Ratio = 1.15
#
#
# Simulation Run = 915
# Weights = [0.093 0.204 0.107 0.069 0.232 0.128 0.167], Final Value = $5430721.44, Sharpe Ratio = 1.04
#
#
# Simulation Run = 916
# Weights = [0.145 0.242 0.001 0.245 0.245 0.089 0.033], Final Value = $4128988.35, Sharpe Ratio = 0.88
#
#
# Simulation Run = 917
# Weights = [0.272 0.141 0.133 0.121 0.093 0.191 0.048], Final Value = $5542415.82, Sharpe Ratio = 1.04
#
#
# Simulation Run = 918
# Weights = [0.091 0.008 0.144 0.207 0.204 0.187 0.158], Final Value = $6069175.43, Sharpe Ratio = 1.09
#
#
# Simulation Run = 919
# Weights = [0.042 0.17  0.245 0.153 0.197 0.062 0.131], Final Value = $4319628.81, Sharpe Ratio = 0.93
#
#
# Simulation Run = 920
# Weights = [0.028 0.057 0.124 0.251 0.128 0.128 0.284], Final Value = $6056532.36, Sharpe Ratio = 1.06
#
#
# Simulation Run = 921
# Weights = [0.253 0.038 0.233 0.078 0.199 0.08  0.119], Final Value = $5033073.09, Sharpe Ratio = 1.06
#
#
# Simulation Run = 922
# Weights = [0.127 0.261 0.181 0.276 0.114 0.007 0.034], Final Value = $3054660.63, Sharpe Ratio = 0.76
#
#
# Simulation Run = 923
# Weights = [0.09  0.085 0.139 0.003 0.298 0.131 0.254], Final Value = $6262404.72, Sharpe Ratio = 1.12
#
#
# Simulation Run = 924
# Weights = [0.028 0.229 0.276 0.37  0.005 0.01  0.082], Final Value = $3069498.57, Sharpe Ratio = 0.73
#
#
# Simulation Run = 925
# Weights = [0.212 0.002 0.029 0.376 0.125 0.017 0.239], Final Value = $5006855.94, Sharpe Ratio = 1.00
#
#
# Simulation Run = 926
# Weights = [0.233 0.048 0.189 0.065 0.363 0.019 0.083], Final Value = $4274387.32, Sharpe Ratio = 1.01
#
#
# Simulation Run = 927
# Weights = [0.006 0.094 0.386 0.302 0.148 0.014 0.05 ], Final Value = $3118354.36, Sharpe Ratio = 0.76
#
#
# Simulation Run = 928
# Weights = [0.003 0.208 0.09  0.151 0.117 0.163 0.269], Final Value = $6163549.72, Sharpe Ratio = 1.04
#
#
# Simulation Run = 929
# Weights = [0.132 0.122 0.158 0.131 0.384 0.001 0.072], Final Value = $3719954.13, Sharpe Ratio = 0.92
#
#
# Simulation Run = 930
# Weights = [0.174 0.221 0.105 0.049 0.247 0.071 0.133], Final Value = $4788502.36, Sharpe Ratio = 1.01
#
#
# Simulation Run = 931
# Weights = [0.115 0.178 0.116 0.171 0.025 0.2   0.195], Final Value = $6198073.61, Sharpe Ratio = 1.06
#
#
# Simulation Run = 932
# Weights = [0.255 0.109 0.114 0.038 0.247 0.087 0.149], Final Value = $5348004.11, Sharpe Ratio = 1.09
#
#
# Simulation Run = 933
# Weights = [0.147 0.055 0.176 0.237 0.1   0.149 0.136], Final Value = $5472319.96, Sharpe Ratio = 1.04
#
#
# Simulation Run = 934
# Weights = [0.206 0.267 0.172 0.176 0.061 0.033 0.085], Final Value = $3838420.11, Sharpe Ratio = 0.87
#
#
# Simulation Run = 935
# Weights = [0.176 0.176 0.204 0.083 0.146 0.191 0.023], Final Value = $5183724.52, Sharpe Ratio = 0.99
#
#
# Simulation Run = 936
# Weights = [0.03  0.196 0.065 0.047 0.262 0.182 0.219], Final Value = $6276125.52, Sharpe Ratio = 1.09
#
#
# Simulation Run = 937
# Weights = [0.112 0.197 0.214 0.046 0.181 0.123 0.128], Final Value = $5090816.38, Sharpe Ratio = 1.01
#
#
# Simulation Run = 938
# Weights = [0.384 0.012 0.165 0.059 0.025 0.171 0.185], Final Value = $6596289.55, Sharpe Ratio = 1.17
#
#
# Simulation Run = 939
# Weights = [0.121 0.198 0.049 0.222 0.175 0.054 0.181], Final Value = $4722507.15, Sharpe Ratio = 0.97
#
#
# Simulation Run = 940
# Weights = [0.286 0.267 0.143 0.023 0.146 0.088 0.049], Final Value = $4480401.00, Sharpe Ratio = 0.96
#
#
# Simulation Run = 941
# Weights = [0.036 0.292 0.107 0.085 0.114 0.293 0.074], Final Value = $6171249.82, Sharpe Ratio = 1.01
#
#
# Simulation Run = 942
# Weights = [0.03  0.144 0.153 0.223 0.208 0.067 0.176], Final Value = $4682349.58, Sharpe Ratio = 0.96
#
#
# Simulation Run = 943
# Weights = [0.054 0.225 0.106 0.071 0.094 0.271 0.179], Final Value = $6760100.86, Sharpe Ratio = 1.09
#
#
# Simulation Run = 944
# Weights = [0.205 0.046 0.13  0.129 0.126 0.159 0.206], Final Value = $6272595.88, Sharpe Ratio = 1.13
#
#
# Simulation Run = 945
# Weights = [0.274 0.241 0.131 0.025 0.191 0.033 0.105], Final Value = $4347583.05, Sharpe Ratio = 0.98
#
#
# Simulation Run = 946
# Weights = [0.071 0.074 0.14  0.169 0.245 0.102 0.199], Final Value = $5421104.71, Sharpe Ratio = 1.05
#
#
# Simulation Run = 947
# Weights = [0.025 0.287 0.103 0.148 0.336 0.031 0.07 ], Final Value = $3598665.22, Sharpe Ratio = 0.84
#
#
# Simulation Run = 948
# Weights = [0.144 0.184 0.01  0.022 0.262 0.222 0.154], Final Value = $6521622.88, Sharpe Ratio = 1.12
#
#
# Simulation Run = 949
# Weights = [0.141 0.171 0.199 0.1   0.171 0.197 0.021], Final Value = $5178649.01, Sharpe Ratio = 0.99
#
#
# Simulation Run = 950
# Weights = [0.149 0.233 0.173 0.042 0.075 0.122 0.206], Final Value = $5586613.39, Sharpe Ratio = 1.04
#
#
# Simulation Run = 951
# Weights = [0.197 0.167 0.149 0.001 0.203 0.23  0.053], Final Value = $5953844.65, Sharpe Ratio = 1.08
#
#
# Simulation Run = 952
# Weights = [0.131 0.075 0.246 0.284 0.124 0.122 0.018], Final Value = $4307057.97, Sharpe Ratio = 0.89
#
#
# Simulation Run = 953
# Weights = [0.178 0.108 0.147 0.096 0.17  0.167 0.135], Final Value = $5805212.18, Sharpe Ratio = 1.09
#
#
# Simulation Run = 954
# Weights = [0.216 0.12  0.035 0.204 0.078 0.214 0.134], Final Value = $6241518.58, Sharpe Ratio = 1.09
#
#
# Simulation Run = 955
# Weights = [0.008 0.187 0.08  0.077 0.136 0.32  0.191], Final Value = $7338271.02, Sharpe Ratio = 1.12
#
#
# Simulation Run = 956
# Weights = [0.179 0.146 0.162 0.178 0.166 0.158 0.012], Final Value = $4781386.61, Sharpe Ratio = 0.95
#
#
# Simulation Run = 957
# Weights = [0.228 0.095 0.032 0.155 0.17  0.208 0.112], Final Value = $6184128.93, Sharpe Ratio = 1.11
#
#
# Simulation Run = 958
# Weights = [0.021 0.207 0.204 0.117 0.059 0.22  0.173], Final Value = $6063792.85, Sharpe Ratio = 1.04
#
#
# Simulation Run = 959
# Weights = [0.189 0.177 0.001 0.316 0.237 0.027 0.053], Final Value = $3740302.72, Sharpe Ratio = 0.86
#
#
# Simulation Run = 960
# Weights = [0.189 0.162 0.036 0.21  0.152 0.167 0.084], Final Value = $5375550.54, Sharpe Ratio = 1.02
#
#
# Simulation Run = 961
# Weights = [0.054 0.179 0.032 0.243 0.1   0.217 0.176], Final Value = $6171183.99, Sharpe Ratio = 1.04
#
#
# Simulation Run = 962
# Weights = [0.234 0.117 0.043 0.222 0.112 0.232 0.041], Final Value = $5839646.41, Sharpe Ratio = 1.04
#
#
# Simulation Run = 963
# Weights = [0.028 0.149 0.327 0.151 0.013 0.045 0.287], Final Value = $5031541.72, Sharpe Ratio = 0.97
#
#
# Simulation Run = 964
# Weights = [0.013 0.239 0.171 0.137 0.221 0.142 0.077], Final Value = $4688950.64, Sharpe Ratio = 0.93
#
#
# Simulation Run = 965
# Weights = [0.095 0.233 0.079 0.112 0.091 0.222 0.168], Final Value = $6242148.47, Sharpe Ratio = 1.06
#
#
# Simulation Run = 966
# Weights = [0.064 0.198 0.164 0.261 0.056 0.11  0.146], Final Value = $4780121.47, Sharpe Ratio = 0.94
#
#
# Simulation Run = 967
# Weights = [0.01  0.106 0.115 0.23  0.217 0.156 0.165], Final Value = $5538383.63, Sharpe Ratio = 1.02
#
#
# Simulation Run = 968
# Weights = [0.206 0.165 0.014 0.016 0.164 0.212 0.223], Final Value = $6946006.71, Sharpe Ratio = 1.15
#
#
# Simulation Run = 969
# Weights = [0.19  0.002 0.258 0.168 0.102 0.267 0.012], Final Value = $5987246.13, Sharpe Ratio = 1.05
#
#
# Simulation Run = 970
# Weights = [0.197 0.036 0.229 0.222 0.089 0.158 0.068], Final Value = $5206797.22, Sharpe Ratio = 1.01
#
#
# Simulation Run = 971
# Weights = [0.296 0.016 0.021 0.119 0.126 0.104 0.317], Final Value = $6729645.86, Sharpe Ratio = 1.16
#
#
# Simulation Run = 972
# Weights = [0.049 0.275 0.048 0.23  0.247 0.109 0.043], Final Value = $4170177.48, Sharpe Ratio = 0.87
#
#
# Simulation Run = 973
# Weights = [0.149 0.213 0.206 0.184 0.023 0.108 0.118], Final Value = $4731390.33, Sharpe Ratio = 0.95
#
#
# Simulation Run = 974
# Weights = [0.032 0.241 0.251 0.177 0.105 0.155 0.038], Final Value = $4455689.62, Sharpe Ratio = 0.88
#
#
# Simulation Run = 975
# Weights = [0.237 0.021 0.112 0.204 0.111 0.162 0.154], Final Value = $5992146.77, Sharpe Ratio = 1.10
#
#
# Simulation Run = 976
# Weights = [0.354 0.29  0.143 0.156 0.027 0.008 0.021], Final Value = $3420139.40, Sharpe Ratio = 0.83
#
#
# Simulation Run = 977
# Weights = [0.269 0.173 0.175 0.049 0.032 0.188 0.116], Final Value = $5901957.83, Sharpe Ratio = 1.08
#
#
# Simulation Run = 978
# Weights = [0.046 0.139 0.204 0.258 0.199 0.059 0.095], Final Value = $4043924.01, Sharpe Ratio = 0.89
#
#
# Simulation Run = 979
# Weights = [0.169 0.149 0.127 0.074 0.003 0.27  0.209], Final Value = $7178203.19, Sharpe Ratio = 1.14
#
#
# Simulation Run = 980
# Weights = [0.088 0.081 0.191 0.079 0.213 0.202 0.147], Final Value = $6118547.96, Sharpe Ratio = 1.10
#
#
# Simulation Run = 981
# Weights = [0.205 0.106 0.069 0.14  0.175 0.195 0.11 ], Final Value = $5980543.78, Sharpe Ratio = 1.09
#
#
# Simulation Run = 982
# Weights = [0.071 0.083 0.18  0.025 0.183 0.26  0.198], Final Value = $7039624.16, Sharpe Ratio = 1.15
#
#
# Simulation Run = 983
# Weights = [0.216 0.077 0.058 0.115 0.272 0.234 0.029], Final Value = $5972173.70, Sharpe Ratio = 1.08
#
#
# Simulation Run = 984
# Weights = [0.164 0.113 0.212 0.163 0.116 0.027 0.205], Final Value = $4713452.09, Sharpe Ratio = 1.00
#
#
# Simulation Run = 985
# Weights = [0.057 0.099 0.177 0.131 0.239 0.135 0.162], Final Value = $5452900.27, Sharpe Ratio = 1.05
#
#
# Simulation Run = 986
# Weights = [0.05  0.215 0.123 0.17  0.047 0.025 0.37 ], Final Value = $5453906.43, Sharpe Ratio = 0.98
#
#
# Simulation Run = 987
# Weights = [0.225 0.013 0.076 0.173 0.118 0.218 0.176], Final Value = $6740272.00, Sharpe Ratio = 1.15
#
#
# Simulation Run = 988
# Weights = [0.18  0.12  0.098 0.152 0.157 0.176 0.117], Final Value = $5740064.56, Sharpe Ratio = 1.07
#
#
# Simulation Run = 989
# Weights = [0.216 0.205 0.203 0.094 0.027 0.039 0.216], Final Value = $4886562.18, Sharpe Ratio = 1.00
#
#
# Simulation Run = 990
# Weights = [0.168 0.127 0.143 0.158 0.158 0.142 0.105], Final Value = $5254642.79, Sharpe Ratio = 1.03
#
#
# Simulation Run = 991
# Weights = [0.125 0.236 0.05  0.161 0.178 0.181 0.07 ], Final Value = $5265754.26, Sharpe Ratio = 0.99
#
#
# Simulation Run = 992
# Weights = [0.128 0.085 0.102 0.144 0.225 0.298 0.017], Final Value = $6302441.04, Sharpe Ratio = 1.06
#
#
# Simulation Run = 993
# Weights = [0.158 0.126 0.122 0.265 0.142 0.092 0.095], Final Value = $4589653.37, Sharpe Ratio = 0.95
#
#
# Simulation Run = 994
# Weights = [0.13  0.051 0.014 0.351 0.161 0.008 0.285], Final Value = $5053250.45, Sharpe Ratio = 0.99
#
#
# Simulation Run = 995
# Weights = [0.073 0.061 0.097 0.204 0.182 0.197 0.186], Final Value = $6261288.12, Sharpe Ratio = 1.09
#
#
# Simulation Run = 996
# Weights = [0.106 0.127 0.132 0.166 0.145 0.126 0.197], Final Value = $5586843.99, Sharpe Ratio = 1.05
#
#
# Simulation Run = 997
# Weights = [0.062 0.103 0.114 0.028 0.203 0.222 0.268], Final Value = $7127096.93, Sharpe Ratio = 1.15
#
#
# Simulation Run = 998
# Weights = [0.025 0.157 0.175 0.17  0.155 0.168 0.151], Final Value = $5497463.17, Sharpe Ratio = 1.02
#
#
# Simulation Run = 999
# Weights = [0.22  0.209 0.195 0.084 0.017 0.065 0.21 ], Final Value = $5118924.19, Sharpe Ratio = 1.02

# %% [markdown]
# ## 11.2 Portfolio Optimization
